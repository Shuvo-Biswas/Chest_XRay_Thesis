# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Covid)','Normal']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/chest_xray_dataset3200/train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size+3, image_size+3))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 2070/2070 [00:39<00:00, 52.94it/s]
# 100%|██████████| 1130/1130 [00:18<00:00, 60.25it/s]

# %%
X_train.shape
# Out:
# (3200, 227, 227, 3)

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model

from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow

# %% [markdown]
# Model Build

# %%
from tensorflow.keras.layers import Input, Conv2D, \
     BatchNormalization, MaxPool2D, Flatten, Dense, Dropout

input = Input(shape=(227, 227, 3))

x = Conv2D(filters=96, kernel_size=11,
           strides=4,
           activation='relu')(input)  # 1st convolutional layer
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=3, strides=2)(x)

x = Conv2D(filters=256,
           kernel_size=5,
           padding='same',
           activation='relu')(x)  # 2nd convolutional layer
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=3, strides=2)(x)

x = Conv2D(filters=384,
           kernel_size=3,
           padding='same',
           activation='relu')(x)  # 3rd convolutional layer

x = Conv2D(filters=384,
           kernel_size=3,
           padding='same',
           activation='relu')(x)  # 4th convolutional layer

x = Conv2D(filters=256,
           kernel_size=3,
           padding='same',
           activation='relu')(x)  # 5th convolutional layer
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=3, strides=2)(x)

x = Flatten()(x)
x = Dropout(rate=0.5)(x)
x = Dense(units=4096, activation='relu')(x)
x = Dropout(rate=0.5)(x)
x = Dense(units=4096, activation='relu')(x)
x = Dense(units=2, activation='softmax')(x)

# %%
# Create model.
inputs = input
model =  keras.Model(inputs, x, name='AlexNet')
model.summary()
# Out:
# Model: "AlexNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv2d (Conv2D)             (None, 55, 55, 96)        34944
#
#  batch_normalization (BatchN  (None, 55, 55, 96)       384
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 27, 27, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 384)       885120
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       884992
#
#  batch_normalization_2 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dropout (Dropout)           (None, 9216)              0
#
#  dense (Dense)               (None, 4096)              37752832
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 2)                 8194
#
# =================================================================
# Total params: 58,291,970
# Trainable params: 58,290,754
# Non-trainable params: 1,216
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("AlexNet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.05, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 86/86 [==============================] - ETA: 0s - loss: 2.5014 - accuracy: 0.8787
# Epoch 1: val_accuracy improved from -inf to 0.72917, saving model to AlexNet.h5
# 86/86 [==============================] - 21s 103ms/step - loss: 2.5014 - accuracy: 0.8787 - val_loss: 0.9308 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 2/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1847 - accuracy: 0.9485
# Epoch 2: val_accuracy improved from 0.72917 to 0.91667, saving model to AlexNet.h5
# 86/86 [==============================] - 7s 77ms/step - loss: 0.1847 - accuracy: 0.9485 - val_loss: 0.2753 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 3/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.1631 - accuracy: 0.9570
# Epoch 3: val_accuracy did not improve from 0.91667
# 86/86 [==============================] - 4s 50ms/step - loss: 0.1626 - accuracy: 0.9569 - val_loss: 0.6379 - val_accuracy: 0.7986 - lr: 0.0010
# Epoch 4/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.1507 - accuracy: 0.9599
# Epoch 4: val_accuracy did not improve from 0.91667
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 86/86 [==============================] - 5s 55ms/step - loss: 0.1506 - accuracy: 0.9594 - val_loss: 0.3959 - val_accuracy: 0.8819 - lr: 0.0010
# Epoch 5/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9620
# Epoch 5: val_accuracy did not improve from 0.91667
# 86/86 [==============================] - 4s 49ms/step - loss: 0.1234 - accuracy: 0.9620 - val_loss: 0.4355 - val_accuracy: 0.8958 - lr: 4.0000e-04
# Epoch 6/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0912 - accuracy: 0.9695
# Epoch 6: val_accuracy improved from 0.91667 to 0.96528, saving model to AlexNet.h5
# 86/86 [==============================] - 7s 77ms/step - loss: 0.0930 - accuracy: 0.9689 - val_loss: 0.1323 - val_accuracy: 0.9653 - lr: 4.0000e-04
# Epoch 7/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0862 - accuracy: 0.9757
# Epoch 7: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 4s 49ms/step - loss: 0.0857 - accuracy: 0.9759 - val_loss: 0.1285 - val_accuracy: 0.9583 - lr: 4.0000e-04
# Epoch 8/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0883 - accuracy: 0.9735
# Epoch 8: val_accuracy did not improve from 0.96528
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 86/86 [==============================] - 4s 48ms/step - loss: 0.0878 - accuracy: 0.9737 - val_loss: 0.2146 - val_accuracy: 0.9653 - lr: 4.0000e-04
# Epoch 9/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0846 - accuracy: 0.9724
# Epoch 9: val_accuracy improved from 0.96528 to 0.97222, saving model to AlexNet.h5
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0849 - accuracy: 0.9719 - val_loss: 0.0851 - val_accuracy: 0.9722 - lr: 1.6000e-04
# Epoch 10/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0669 - accuracy: 0.9779
# Epoch 10: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 5s 56ms/step - loss: 0.0665 - accuracy: 0.9781 - val_loss: 0.0790 - val_accuracy: 0.9653 - lr: 1.6000e-04
# Epoch 11/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0677 - accuracy: 0.9776
# Epoch 11: val_accuracy improved from 0.97222 to 0.97917, saving model to AlexNet.h5
# 86/86 [==============================] - 7s 79ms/step - loss: 0.0694 - accuracy: 0.9770 - val_loss: 0.0786 - val_accuracy: 0.9792 - lr: 1.6000e-04
# Epoch 12/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0537 - accuracy: 0.9809
# Epoch 12: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0535 - accuracy: 0.9810 - val_loss: 0.0759 - val_accuracy: 0.9722 - lr: 1.6000e-04
# Epoch 13/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0576 - accuracy: 0.9794
# Epoch 13: val_accuracy did not improve from 0.97917
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 86/86 [==============================] - 5s 55ms/step - loss: 0.0593 - accuracy: 0.9792 - val_loss: 0.0682 - val_accuracy: 0.9722 - lr: 1.6000e-04
# Epoch 14/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.9827
# Epoch 14: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0476 - accuracy: 0.9828 - val_loss: 0.0643 - val_accuracy: 0.9722 - lr: 6.4000e-05
# Epoch 15/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0434 - accuracy: 0.9842
# Epoch 15: val_accuracy did not improve from 0.97917
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0432 - accuracy: 0.9843 - val_loss: 0.0779 - val_accuracy: 0.9722 - lr: 6.4000e-05
# Epoch 16/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0445 - accuracy: 0.9857
# Epoch 16: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 50ms/step - loss: 0.0443 - accuracy: 0.9857 - val_loss: 0.0624 - val_accuracy: 0.9722 - lr: 2.5600e-05
# Epoch 17/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0385 - accuracy: 0.9853
# Epoch 17: val_accuracy did not improve from 0.97917
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0383 - accuracy: 0.9854 - val_loss: 0.0621 - val_accuracy: 0.9722 - lr: 2.5600e-05
# Epoch 18/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0399 - accuracy: 0.9875
# Epoch 18: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0397 - accuracy: 0.9876 - val_loss: 0.0616 - val_accuracy: 0.9722 - lr: 1.0240e-05
# Epoch 19/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0362 - accuracy: 0.9875
# Epoch 19: val_accuracy did not improve from 0.97917
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0362 - accuracy: 0.9876 - val_loss: 0.0629 - val_accuracy: 0.9722 - lr: 1.0240e-05
# Epoch 20/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9865
# Epoch 20: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0425 - accuracy: 0.9865 - val_loss: 0.0635 - val_accuracy: 0.9722 - lr: 4.0960e-06
# Epoch 21/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9868
# Epoch 21: val_accuracy did not improve from 0.97917
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0376 - accuracy: 0.9868 - val_loss: 0.0633 - val_accuracy: 0.9722 - lr: 4.0960e-06
# Epoch 22/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0377 - accuracy: 0.9883
# Epoch 22: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0377 - accuracy: 0.9883 - val_loss: 0.0632 - val_accuracy: 0.9722 - lr: 1.6384e-06
# Epoch 23/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9871
# Epoch 23: val_accuracy did not improve from 0.97917
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0349 - accuracy: 0.9872 - val_loss: 0.0633 - val_accuracy: 0.9722 - lr: 1.6384e-06
# Epoch 24/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9886
# Epoch 24: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0358 - accuracy: 0.9887 - val_loss: 0.0635 - val_accuracy: 0.9722 - lr: 6.5536e-07
# Epoch 25/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9875
# Epoch 25: val_accuracy did not improve from 0.97917
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0367 - accuracy: 0.9876 - val_loss: 0.0637 - val_accuracy: 0.9722 - lr: 6.5536e-07
# Epoch 26/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9864
# Epoch 26: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0368 - accuracy: 0.9861 - val_loss: 0.0632 - val_accuracy: 0.9722 - lr: 2.6214e-07
# Epoch 27/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0355 - accuracy: 0.9875
# Epoch 27: val_accuracy did not improve from 0.97917
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0363 - accuracy: 0.9872 - val_loss: 0.0638 - val_accuracy: 0.9722 - lr: 2.6214e-07
# Epoch 28/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0348 - accuracy: 0.9868
# Epoch 28: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 50ms/step - loss: 0.0346 - accuracy: 0.9868 - val_loss: 0.0635 - val_accuracy: 0.9722 - lr: 1.0486e-07
# Epoch 29/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0427 - accuracy: 0.9857
# Epoch 29: val_accuracy did not improve from 0.97917
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0425 - accuracy: 0.9857 - val_loss: 0.0633 - val_accuracy: 0.9722 - lr: 1.0486e-07
# Epoch 30/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9861
# Epoch 30: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0368 - accuracy: 0.9861 - val_loss: 0.0634 - val_accuracy: 0.9722 - lr: 4.1943e-08
# Epoch 31/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0350 - accuracy: 0.9875
# Epoch 31: val_accuracy did not improve from 0.97917
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 86/86 [==============================] - 5s 54ms/step - loss: 0.0349 - accuracy: 0.9876 - val_loss: 0.0636 - val_accuracy: 0.9722 - lr: 4.1943e-08
# Epoch 32/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0386 - accuracy: 0.9846
# Epoch 32: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0388 - accuracy: 0.9843 - val_loss: 0.0634 - val_accuracy: 0.9722 - lr: 1.6777e-08
# Epoch 33/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9861
# Epoch 33: val_accuracy did not improve from 0.97917
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.710887134886434e-09.
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0384 - accuracy: 0.9861 - val_loss: 0.0635 - val_accuracy: 0.9722 - lr: 1.6777e-08
# Epoch 34/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9879
# Epoch 34: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0334 - accuracy: 0.9879 - val_loss: 0.0636 - val_accuracy: 0.9722 - lr: 6.7109e-09
# Epoch 35/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9894
# Epoch 35: val_accuracy did not improve from 0.97917
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.6843547829003003e-09.
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0321 - accuracy: 0.9894 - val_loss: 0.0636 - val_accuracy: 0.9722 - lr: 6.7109e-09
# Epoch 36/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0356 - accuracy: 0.9871
# Epoch 36: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 5s 57ms/step - loss: 0.0354 - accuracy: 0.9872 - val_loss: 0.0637 - val_accuracy: 0.9722 - lr: 2.6844e-09
# Epoch 37/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0384 - accuracy: 0.9849
# Epoch 37: val_accuracy did not improve from 0.97917
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.0737418953965518e-09.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0382 - accuracy: 0.9850 - val_loss: 0.0639 - val_accuracy: 0.9722 - lr: 2.6844e-09
# Epoch 38/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9875
# Epoch 38: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0335 - accuracy: 0.9876 - val_loss: 0.0636 - val_accuracy: 0.9722 - lr: 1.0737e-09
# Epoch 39/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0347 - accuracy: 0.9886
# Epoch 39: val_accuracy did not improve from 0.97917
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 4.294967492768365e-10.
# 86/86 [==============================] - 5s 54ms/step - loss: 0.0345 - accuracy: 0.9887 - val_loss: 0.0634 - val_accuracy: 0.9722 - lr: 1.0737e-09
# Epoch 40/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0334 - accuracy: 0.9886
# Epoch 40: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0332 - accuracy: 0.9887 - val_loss: 0.0633 - val_accuracy: 0.9722 - lr: 4.2950e-10
# Epoch 41/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9871
# Epoch 41: val_accuracy did not improve from 0.97917
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.7179869749028854e-10.
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0331 - accuracy: 0.9872 - val_loss: 0.0637 - val_accuracy: 0.9722 - lr: 4.2950e-10
# Epoch 42/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0338 - accuracy: 0.9868
# Epoch 42: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0340 - accuracy: 0.9865 - val_loss: 0.0638 - val_accuracy: 0.9722 - lr: 1.7180e-10
# Epoch 43/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9860
# Epoch 43: val_accuracy did not improve from 0.97917
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.871948010633844e-11.
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0357 - accuracy: 0.9861 - val_loss: 0.0639 - val_accuracy: 0.9722 - lr: 1.7180e-10
# Epoch 44/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9901
# Epoch 44: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 50ms/step - loss: 0.0297 - accuracy: 0.9901 - val_loss: 0.0638 - val_accuracy: 0.9722 - lr: 6.8719e-11
# Epoch 45/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9868
# Epoch 45: val_accuracy did not improve from 0.97917
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.748779259764689e-11.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0377 - accuracy: 0.9868 - val_loss: 0.0636 - val_accuracy: 0.9722 - lr: 6.8719e-11
# Epoch 46/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9868
# Epoch 46: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 50ms/step - loss: 0.0349 - accuracy: 0.9868 - val_loss: 0.0639 - val_accuracy: 0.9722 - lr: 2.7488e-11
# Epoch 47/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9890
# Epoch 47: val_accuracy did not improve from 0.97917
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.0995117316614512e-11.
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0341 - accuracy: 0.9890 - val_loss: 0.0642 - val_accuracy: 0.9722 - lr: 2.7488e-11
# Epoch 48/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.9890
# Epoch 48: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0356 - accuracy: 0.9890 - val_loss: 0.0637 - val_accuracy: 0.9722 - lr: 1.0995e-11
# Epoch 49/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9875
# Epoch 49: val_accuracy did not improve from 0.97917
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 4.398046857256866e-12.
# 86/86 [==============================] - 4s 51ms/step - loss: 0.0347 - accuracy: 0.9876 - val_loss: 0.0637 - val_accuracy: 0.9722 - lr: 1.0995e-11
# Epoch 50/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0348 - accuracy: 0.9879
# Epoch 50: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 4s 52ms/step - loss: 0.0352 - accuracy: 0.9876 - val_loss: 0.0634 - val_accuracy: 0.9722 - lr: 4.3980e-12

# %%
#plot the loss curve
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.ylabel('Loss',fontweight='bold')
plt.title('Loss Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('Covid_AlexNet_LossCurve',dpi=400)
plt.legend()

# %%
#plot the accuracy curve
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.ylabel('Accuracy',fontweight='bold')
plt.title('Accuracy Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('Covid_AlexNet_AccCurve',dpi=400)
plt.legend()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 10/10 [==============================] - 0s 17ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       210
#            1       0.97      0.97      0.97       110
#
#     accuracy                           0.98       320
#    macro avg       0.98      0.98      0.98       320
# weighted avg       0.98      0.98      0.98       320

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm,labels)
plt.savefig('AlexNetCM',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.5f' % accuracy_score(y_test_new, pred), 'Precision: %.5f' % precision_score(y_test_new, pred),' Recall: %.5f' % recall_score(y_test_new, pred), 
      'F1 Score: %.5f' % f1_score(y_test_new, pred), 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.98125 Precision: 0.97273  Recall: 0.97273 F1 Score: 0.97273 AUC Score: 0.97922

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
print('TP = %.5f'%TP, 'TN = %.5f'%TN, 'FP = %.5f'%FP, 'FN = %.5f'%FN)
# Out:
# TP = 107.00000 TN = 207.00000 FP = 3.00000 FN = 3.00000

# %%
specificity=TN/float(TN+FP)
print('Specificity: %.5f' % specificity)
# Out:
# Specificity: 0.98571

# %%
recall=TP/float(TP+FN)
print(' Recall: %.5f' % recall)
precision=TP/float(TP+FP)
print(' Precision: %.5f' % precision)
# Out:
#  Recall: 0.97273
#  Precision: 0.97273

# %%
f1=(2*precision*recall)/(recall+precision)
print('F1 Score: %.5f' % f1)
# Out:
# F1 Score: 0.97273

# %%
print( 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# AUC Score: 0.97922

# %%
from sklearn.metrics import mean_squared_error
print( 'Error Rate: %.5f' % mean_squared_error(y_test_new, pred))
# Out:
# Error Rate: 0.01875

# %%
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.ylabel('Recall')
plt.xlabel('Fall-out (1-Specificity)')
plt.savefig('Covid_AlexNetAUC',dpi=400)
plt.show()

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
print('val_accuracy: {0:0.2f}%'.format(np.round((history.history['val_accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 98.12%
# Precision: 97.27%
# Recall or Sensitivity: 97.27%
# Specificity: 98.57%
# F1-score: 97.27%
# AUC-score: 97.92%
# Train acc: 98.76%
# val_accuracy: 97.22%

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score
from scipy import interp
from itertools import cycle

# %%
# Plot linewidth.
lw = 1

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test_new, pred)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_new.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(2)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(2):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= 2

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
plt.title('Receiver Operating Characteristic (ROC) Curve')
# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'cornflowerblue'])
for i, color in zip(range(2), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.savefig('Covid_AlexNet_ROC',dpi=400)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_auc_score

# %%
n_classes=2

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange"])
for i, color in zip(range(n_classes), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.2f})".format(i, roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.show()
