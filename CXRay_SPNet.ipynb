# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal','Normal']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/Chest_XRay_Dataset/train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 1870/1870 [12:33<00:00,  2.48it/s]
# 100%|██████████| 1340/1340 [00:18<00:00, 71.20it/s]

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model
import keras.backend as k
from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
from keras.utils.vis_utils import plot_model
from keras.initializers import glorot_uniform
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D

# %%
k.clear_session()
def inception_module(x, f1, f2, f3, f4):
		# 1x1 conv
		conv1 = keras.layers.Conv2D(f1, (1,1), strides=(1, 1), padding='same', activation='relu')(x)
		# 3x3 conv
		conv3 = keras.layers.Conv2D(f2, (3,3), strides=(1, 1), padding='same', activation='relu')(x)
		# 5x5 conv
		conv5 = keras.layers.Conv2D(f3, (5,5), strides=(1, 1), padding='same', activation='relu')(x)
		conv7 = keras.layers.Conv2D(f4, (7,7), strides=(1, 1), padding='same', activation='relu')(x)
		x = keras.layers.concatenate([conv1, conv3, conv5, conv7])
		return x

# %%
def conv2d_bn(x,filters,num_row,num_col,padding='same',strides=(1, 1)):
   
    x = keras.layers.Conv2D(filters, (num_row, num_col),strides=strides,padding=padding)(x)
    x = keras.layers.BatchNormalization(axis=3, scale=False)(x)
    x = keras.layers.Activation('relu')(x)
    return x

# %%
img_input = keras.Input(shape=(224, 224, 3))  #shape=(None, 299, 299, 3)

# %%
#OURmODELv6
#conv2d_bn(x,filters,num_row,num_col,padding='same',strides=(1, 1))
x = conv2d_bn(img_input, 64, 7, 7, strides=(2, 2), padding='same') # 149 x 149 x 32
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)   # 73  x 73 x 64

x = conv2d_bn(x, 64, 1, 1, padding='same')  # 147 x 147 x 32
x = conv2d_bn(x, 192, 3, 3, padding='same') # 147 x 147 x 64
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)   # 73  x 73 x 64

#inception_module(x, f1, f2, f3)
x = inception_module(x, 128, 128, 128, 128)
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)  # 35 x 35 x 512

x = inception_module(x, 192, 192, 192, 192)
x = inception_module(x, 256, 256, 256, 256)
x = inception_module(x, 256, 256, 256, 256)
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)  # 35 x 35 x 512

x = inception_module(x, 512, 512, 512, 512)
x = keras.layers.MaxPooling2D((7, 7), strides=(1, 1))(x)  # 35 x 35 x 192

#x = keras.layers.GlobalAveragePooling2D(name='avg_pool')(x) # shape=(None, 2048)
x = Flatten()(x)
x = keras.layers.Dense(1000, activation='relu')(x)
x = keras.layers.Dropout(0.5)(x)
x = keras.layers.Dense(2, activation='softmax', name='predictions')(x) #shape=(None, 1000)

# %%
# Create model.
inputs = img_input
model =  keras.Model(inputs, x, name='DFUEffectiveNetV3')
model.summary()
# Out:
# Model: "DFUEffectiveNetV3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  192        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  192         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 192)  110784      ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 192)  576        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 56, 56, 192)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0          ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  221312      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  614528      ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 128)  1204352     ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 512)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 512)  0          ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 192)  98496       ['max_pooling2d_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 192)  884928      ['max_pooling2d_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 14, 14, 192)  2457792     ['max_pooling2d_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 14, 14, 192)  4817088     ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 14, 14, 768)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 14, 14, 256)  196864      ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 14, 14, 256)  1769728     ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 14, 14, 256)  4915456     ['concatenate_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 14, 14, 256)  9634048     ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 1024  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 256)  262400      ['concatenate_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 256)  2359552     ['concatenate_2[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 256)  6553856     ['concatenate_2[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 256)  12845312    ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 1024  0           ['conv2d_15[0][0]',
#                                 )                                 'conv2d_16[0][0]',
#                                                                   'conv2d_17[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['concatenate_3[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 7, 7, 512)    524800      ['max_pooling2d_3[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 7, 7, 512)    4719104     ['max_pooling2d_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 7, 7, 512)    13107712    ['max_pooling2d_3[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 7, 7, 512)    25690624    ['max_pooling2d_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 7, 7, 2048)   0           ['conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]',
#                                                                   'conv2d_21[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 2048)  0           ['concatenate_4[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['max_pooling2d_4[0][0]']
#
#  dense (Dense)                  (None, 1000)         2049000     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 1000)         0           ['dense[0][0]']
#
#  predictions (Dense)            (None, 2)            2002        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 95,079,034
# Trainable params: 95,078,394
# Non-trainable params: 640
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("Chest_SPNet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.05, epochs =30, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/30
# 86/86 [==============================] - ETA: 0s - loss: 156.0509 - accuracy: 0.7369
# Epoch 1: val_accuracy improved from -inf to 0.38621, saving model to Chest_SPNet.h5
# 86/86 [==============================] - 74s 600ms/step - loss: 156.0509 - accuracy: 0.7369 - val_loss: 1.2665 - val_accuracy: 0.3862 - lr: 0.0010
# Epoch 2/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2135 - accuracy: 0.9173
# Epoch 2: val_accuracy improved from 0.38621 to 0.56552, saving model to Chest_SPNet.h5
# 86/86 [==============================] - 40s 461ms/step - loss: 0.2135 - accuracy: 0.9173 - val_loss: 1.0821 - val_accuracy: 0.5655 - lr: 0.0010
# Epoch 3/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1280 - accuracy: 0.9501
# Epoch 3: val_accuracy improved from 0.56552 to 0.96552, saving model to Chest_SPNet.h5
# 86/86 [==============================] - 40s 468ms/step - loss: 0.1280 - accuracy: 0.9501 - val_loss: 0.1044 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 4/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9672
# Epoch 4: val_accuracy did not improve from 0.96552
# 86/86 [==============================] - 36s 412ms/step - loss: 0.0939 - accuracy: 0.9672 - val_loss: 0.0971 - val_accuracy: 0.9586 - lr: 0.0010
# Epoch 5/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9730
# Epoch 5: val_accuracy did not improve from 0.96552
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 86/86 [==============================] - 36s 416ms/step - loss: 0.0760 - accuracy: 0.9730 - val_loss: 0.0606 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 6/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9829
# Epoch 6: val_accuracy improved from 0.96552 to 0.97931, saving model to Chest_SPNet.h5
# 86/86 [==============================] - 40s 467ms/step - loss: 0.0448 - accuracy: 0.9829 - val_loss: 0.0761 - val_accuracy: 0.9793 - lr: 4.0000e-04
# Epoch 7/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9905
# Epoch 7: val_accuracy did not improve from 0.97931
# 86/86 [==============================] - 36s 416ms/step - loss: 0.0275 - accuracy: 0.9905 - val_loss: 0.0868 - val_accuracy: 0.9724 - lr: 4.0000e-04
# Epoch 8/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9847
# Epoch 8: val_accuracy did not improve from 0.97931
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 86/86 [==============================] - 36s 415ms/step - loss: 0.0367 - accuracy: 0.9847 - val_loss: 0.0958 - val_accuracy: 0.9793 - lr: 4.0000e-04
# Epoch 9/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9978
# Epoch 9: val_accuracy improved from 0.97931 to 0.98621, saving model to Chest_SPNet.h5
# 86/86 [==============================] - 40s 467ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.0786 - val_accuracy: 0.9862 - lr: 1.6000e-04
# Epoch 10/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9989
# Epoch 10: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 416ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 0.0812 - val_accuracy: 0.9862 - lr: 1.6000e-04
# Epoch 11/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9996
# Epoch 11: val_accuracy did not improve from 0.98621
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 86/86 [==============================] - 36s 415ms/step - loss: 0.0047 - accuracy: 0.9996 - val_loss: 0.0927 - val_accuracy: 0.9862 - lr: 1.6000e-04
# Epoch 12/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996
# Epoch 12: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 414ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.0990 - val_accuracy: 0.9793 - lr: 6.4000e-05
# Epoch 13/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.98621
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 86/86 [==============================] - 36s 416ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 0.9793 - lr: 6.4000e-05
# Epoch 14/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 414ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9793 - lr: 2.5600e-05
# Epoch 15/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.98621
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 86/86 [==============================] - 36s 415ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9793 - lr: 2.5600e-05
# Epoch 16/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 16: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 415ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0995 - val_accuracy: 0.9793 - lr: 1.0240e-05
# Epoch 17/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.98621
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 86/86 [==============================] - 36s 414ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0991 - val_accuracy: 0.9793 - lr: 1.0240e-05
# Epoch 18/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9996
# Epoch 18: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 415ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0995 - val_accuracy: 0.9793 - lr: 4.0960e-06
# Epoch 19/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9996
# Epoch 19: val_accuracy did not improve from 0.98621
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 86/86 [==============================] - 36s 415ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0997 - val_accuracy: 0.9793 - lr: 4.0960e-06
# Epoch 20/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 414ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9862 - lr: 1.6384e-06
# Epoch 21/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.98621
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 86/86 [==============================] - 36s 414ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 0.9793 - lr: 1.6384e-06
# Epoch 22/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 414ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9793 - lr: 6.5536e-07
# Epoch 23/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.98621
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 86/86 [==============================] - 36s 416ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 0.9793 - lr: 6.5536e-07
# Epoch 24/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 24: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 414ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0996 - val_accuracy: 0.9793 - lr: 2.6214e-07
# Epoch 25/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.98621
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 86/86 [==============================] - 36s 415ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9793 - lr: 2.6214e-07
# Epoch 26/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 415ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 0.9793 - lr: 1.0486e-07
# Epoch 27/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.98621
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 86/86 [==============================] - 36s 414ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9793 - lr: 1.0486e-07
# Epoch 28/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996
# Epoch 28: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 415ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0998 - val_accuracy: 0.9793 - lr: 4.1943e-08
# Epoch 29/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.98621
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 86/86 [==============================] - 36s 415ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9793 - lr: 4.1943e-08
# Epoch 30/30
# 86/86 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 30: val_accuracy did not improve from 0.98621
# 86/86 [==============================] - 36s 414ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.1000 - val_accuracy: 0.9793 - lr: 1.6777e-08

# %%
#plot the loss curve
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.ylabel('Loss',fontweight='bold')
plt.title('Loss Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('Covid_SPNet_LossCurve',dpi=400)
plt.legend()

# %%
#plot the accuracy curve
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.ylabel('Accuracy',fontweight='bold')
plt.title('Accuracy Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('Covid_SPNet_AccCurve',dpi=400)
plt.legend()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 11/11 [==============================] - 2s 216ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       179
#            1       0.99      0.97      0.98       142
#
#     accuracy                           0.98       321
#    macro avg       0.98      0.98      0.98       321
# weighted avg       0.98      0.98      0.98       321

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True/Actual label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm,labels)
plt.savefig('Covid_SPNet',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
print('TP = %.5f'%TP, 'TN = %.5f'%TN, 'FP = %.5f'%FP, 'FN = %.5f'%FN)
# Out:
# TP = 138.00000 TN = 177.00000 FP = 2.00000 FN = 4.00000

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.5f' % accuracy_score(y_test_new, pred), 'Precision: %.5f' % precision_score(y_test_new, pred),' Recall: %.5f' % recall_score(y_test_new, pred), 
      'F1 Score: %.5f' % f1_score(y_test_new, pred), 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.98131 Precision: 0.98571  Recall: 0.97183 F1 Score: 0.97872 AUC Score: 0.98033

# %%
recall=TP/float(TP+FN)
print(recall)
print(recall_score(y_test_new, pred))
# Out:
# 0.971830985915493
# 0.971830985915493

# %%
precision=TP/float(TP+FP)
print(precision)

print(precision_score(y_test_new, pred))
# Out:
# 0.9857142857142858
# 0.9857142857142858

# %%
print((2*precision*recall)/(recall+precision))
print(f1_score(y_test_new, pred))
# Out:
# 0.9787234042553192
# 0.9787234042553192

# %%
specificity=TN/float(TN+FP)
print(specificity)
# Out:
# 0.9888268156424581

# %%
print(TP/float(TP+FN))
print(recall_score(y_test_new, pred))
# Out:
# 0.971830985915493
# 0.971830985915493

# %%
print(roc_auc_score(y_test_new, pred))
# Out:
# 0.9803289007789755

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test_new, pred)
# Out:
# 0.018691588785046728

# %%
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.4f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.ylabel('Recall')
plt.xlabel('Specificity')
plt.savefig('Covid_SPNet_ROCCurve',dpi=400)
plt.show()

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
print('Validation acc: {0:0.2f}%'.format(np.round((history.history['val_accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 98.13%
# Precision: 98.57%
# Recall or Sensitivity: 97.18%
# Specificity: 98.88%
# F1-score: 97.87%
# AUC-score: 98.03%
# Train acc: 99.96%
# Validation acc: 97.93%

# %%
#need to update with data augmentation

test_image_generator = ImageDataGenerator(
  rescale = 1.0/255)

#class_mode = 'sparse')
test_iterator = test_image_generator.flow_from_directory('/content/drive/MyDrive/Chest_XRay_Dataset/check',
target_size = (224, 224),
batch_size = 32,
color_mode = 'rgb')
#class_mode = 'sparse')
# Out:
# Found 16 images belonging to 2 classes.

# %%
from tensorflow import argmax
from tensorflow import expand_dims
from matplotlib import pyplot as plt


#Take matplotlib frame and remove axes.
def clean_plot(plot):
    plot.axes.get_xaxis().set_visible(False)
    plot.axes.get_yaxis().set_visible(False)

#Dict mapping from class numbers to string labels:
class_names = {
        0: "Abnormal",
        1: "Normal",
    }

#Loads a sample batch of data
sample_batch_input, sample_labels = test_iterator.next()
    
#Grabs the first five images
sample_batch_input = sample_batch_input[:5]
sample_labels = sample_labels[:5]

#Makes predictions using model.predict(x)
sample_predictions = model.predict(sample_batch_input)

#Iterate of images, predictions, and true labels
for i, (image, prediction, label) in enumerate(zip(sample_batch_input, sample_predictions, sample_labels)):

    image_name = "Chest Abnormalities {}".format(i)

    #Gets predicted class with highest probability
    predicted_class = argmax(prediction).numpy()

    #Gets correct label
    actual_class = argmax(label).numpy()

    print(image_name)
    print("\tclass name: [Abnormal]   [Normal]")
    print("\tModel prediction: {}".format(prediction))
    print("\tCategory: {} ({})".format(class_names[actual_class], actual_class))

    #Saves image file using matplotlib
    sample_image = image
    clean_plot(plt.imshow(
    sample_image[:, :, 0],
    cmap = "gray"
        ))
    plt.title("{}".format(class_names[predicted_class]))
    plt.tight_layout()
    plt.show()
    plt.clf()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Chest Abnormalities 0
# 	class name: [Abnormal]   [Normal]
# 	Model prediction: [9.9994969e-01 5.0274437e-05]
# 	Category: Normal (1)
# Chest Abnormalities 1
# 	class name: [Abnormal]   [Normal]
# 	Model prediction: [9.9995029e-01 4.9728995e-05]
# 	Category: Normal (1)
# Chest Abnormalities 2
# 	class name: [Abnormal]   [Normal]
# 	Model prediction: [9.9994957e-01 5.0406405e-05]
# 	Category: Abnormal (0)
# Chest Abnormalities 3
# 	class name: [Abnormal]   [Normal]
# 	Model prediction: [9.9994886e-01 5.1145158e-05]
# 	Category: Normal (1)
# Chest Abnormalities 4
# 	class name: [Abnormal]   [Normal]
# 	Model prediction: [9.9994957e-01 5.0383147e-05]
# 	Category: Abnormal (0)
