# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Covid)','Normal']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/chest_xray_dataset3200/train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 2070/2070 [00:31<00:00, 66.12it/s]
# 100%|██████████| 1130/1130 [00:14<00:00, 80.59it/s]

# %%
X_train.shape
# Out:
# (3200, 224, 224, 3)

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import cv2
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import keras
from keras.models import Sequential, Model,load_model
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping,ModelCheckpoint
from google.colab.patches import cv2_imshow
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform

# %% [markdown]
# Model Build

# %%
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D, BatchNormalization, ReLU, Add
from tensorflow.keras.layers import MaxPool2D, GlobalAvgPool2D, Dense
 
def conv_batchnorm_relu(x, filters, kernel_size, strides):
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=strides,
               padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x
 
def identity_block(tensor, filters):
    x = conv_batchnorm_relu(tensor, filters=filters, kernel_size=1, strides=1)
    x = conv_batchnorm_relu(x, filters=filters, kernel_size=3, strides=1)
    x = Conv2D(filters=4*filters, kernel_size=1, strides=1)(x)  # notice: filters=4*filters
    x = BatchNormalization()(x)
 
    x = Add()([x, tensor])
    x = ReLU()(x)
    return x
 
def projection_block(tensor, filters, strides):
    # left stream
    x = conv_batchnorm_relu(tensor, filters=filters, kernel_size=1, strides=1)
    x = conv_batchnorm_relu(x, filters=filters, kernel_size=3, strides=strides)
    x = Conv2D(filters=4*filters, kernel_size=1, strides=1)(x)  # notice: filters=4*filters
    x = BatchNormalization()(x)
 
    # right stream
    shortcut = Conv2D(filters=4*filters, kernel_size=1, strides=strides)(tensor)  # notice: filters=4*filters
    shortcut = BatchNormalization()(shortcut)
 
    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x
 
def resnet_block(x, filters, reps, strides):
    x = projection_block(x, filters=filters, strides=strides)
    for _ in range(reps-1):  # the -1 is because the first block was a Conv one
        x = identity_block(x, filters=filters)
    return x
 
input = Input(shape=(224, 224, 3))
 
x = conv_batchnorm_relu(input, filters=64, kernel_size=7, strides=2)  # [3]: 7x7, 64, strides 2
x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)  # [3]: 3x3 max mool, strides 2
 
x = resnet_block(x, filters=64, reps=3, strides=1)
x = resnet_block(x, filters=128, reps=8, strides=2)  # s=2 ([2]: conv3_1)
x = resnet_block(x, filters=256, reps=30, strides=2)  # s=2 ([2]: conv4_1)
x = resnet_block(x, filters=512, reps=3, strides=2)  # s=2 ([2]: conv5_1)
 
x = GlobalAvgPool2D()(x)  # [3]: average pool *it is not written any pool size so we use Global
 
output = Dense(2, activation='softmax')(x)  # [3]: 1000-d fc, softmax
 
from tensorflow.keras import Model
 
model = Model(input, output)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_137 (Conv2D)            (None, 112, 112, 64  9472        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_137 (Batch  (None, 112, 112, 64  256        ['conv2d_137[0][0]']
#  Normalization)                 )
#
#  re_lu_133 (ReLU)               (None, 112, 112, 64  0           ['batch_normalization_137[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['re_lu_133[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 56, 56, 64)   4160        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_138 (Batch  (None, 56, 56, 64)  256         ['conv2d_138[0][0]']
#  Normalization)
#
#  re_lu_134 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_138[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 56, 56, 64)   36928       ['re_lu_134[0][0]']
#
#  batch_normalization_139 (Batch  (None, 56, 56, 64)  256         ['conv2d_139[0][0]']
#  Normalization)
#
#  re_lu_135 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_139[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 56, 56, 256)  16640       ['re_lu_135[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 56, 56, 256)  16640       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_140 (Batch  (None, 56, 56, 256)  1024       ['conv2d_140[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 56, 56, 256)  1024       ['conv2d_141[0][0]']
#  Normalization)
#
#  add_44 (Add)                   (None, 56, 56, 256)  0           ['batch_normalization_140[0][0]',
#                                                                   'batch_normalization_141[0][0]']
#
#  re_lu_136 (ReLU)               (None, 56, 56, 256)  0           ['add_44[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 56, 56, 64)   16448       ['re_lu_136[0][0]']
#
#  batch_normalization_142 (Batch  (None, 56, 56, 64)  256         ['conv2d_142[0][0]']
#  Normalization)
#
#  re_lu_137 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_142[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 56, 56, 64)   36928       ['re_lu_137[0][0]']
#
#  batch_normalization_143 (Batch  (None, 56, 56, 64)  256         ['conv2d_143[0][0]']
#  Normalization)
#
#  re_lu_138 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_143[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 56, 56, 256)  16640       ['re_lu_138[0][0]']
#
#  batch_normalization_144 (Batch  (None, 56, 56, 256)  1024       ['conv2d_144[0][0]']
#  Normalization)
#
#  add_45 (Add)                   (None, 56, 56, 256)  0           ['batch_normalization_144[0][0]',
#                                                                   're_lu_136[0][0]']
#
#  re_lu_139 (ReLU)               (None, 56, 56, 256)  0           ['add_45[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 56, 56, 64)   16448       ['re_lu_139[0][0]']
#
#  batch_normalization_145 (Batch  (None, 56, 56, 64)  256         ['conv2d_145[0][0]']
#  Normalization)
#
#  re_lu_140 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_145[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 56, 56, 64)   36928       ['re_lu_140[0][0]']
#
#  batch_normalization_146 (Batch  (None, 56, 56, 64)  256         ['conv2d_146[0][0]']
#  Normalization)
#
#  re_lu_141 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_146[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 56, 56, 256)  16640       ['re_lu_141[0][0]']
#
#  batch_normalization_147 (Batch  (None, 56, 56, 256)  1024       ['conv2d_147[0][0]']
#  Normalization)
#
#  add_46 (Add)                   (None, 56, 56, 256)  0           ['batch_normalization_147[0][0]',
#                                                                   're_lu_139[0][0]']
#
#  re_lu_142 (ReLU)               (None, 56, 56, 256)  0           ['add_46[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 56, 56, 128)  32896       ['re_lu_142[0][0]']
#
#  batch_normalization_148 (Batch  (None, 56, 56, 128)  512        ['conv2d_148[0][0]']
#  Normalization)
#
#  re_lu_143 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 28, 28, 128)  147584      ['re_lu_143[0][0]']
#
#  batch_normalization_149 (Batch  (None, 28, 28, 128)  512        ['conv2d_149[0][0]']
#  Normalization)
#
#  re_lu_144 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_149[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 28, 28, 512)  66048       ['re_lu_144[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 28, 28, 512)  131584      ['re_lu_142[0][0]']
#
#  batch_normalization_150 (Batch  (None, 28, 28, 512)  2048       ['conv2d_150[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 28, 28, 512)  2048       ['conv2d_151[0][0]']
#  Normalization)
#
#  add_47 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_150[0][0]',
#                                                                   'batch_normalization_151[0][0]']
#
#  re_lu_145 (ReLU)               (None, 28, 28, 512)  0           ['add_47[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 28, 28, 128)  65664       ['re_lu_145[0][0]']
#
#  batch_normalization_152 (Batch  (None, 28, 28, 128)  512        ['conv2d_152[0][0]']
#  Normalization)
#
#  re_lu_146 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_152[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 28, 28, 128)  147584      ['re_lu_146[0][0]']
#
#  batch_normalization_153 (Batch  (None, 28, 28, 128)  512        ['conv2d_153[0][0]']
#  Normalization)
#
#  re_lu_147 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_153[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 28, 28, 512)  66048       ['re_lu_147[0][0]']
#
#  batch_normalization_154 (Batch  (None, 28, 28, 512)  2048       ['conv2d_154[0][0]']
#  Normalization)
#
#  add_48 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_154[0][0]',
#                                                                   're_lu_145[0][0]']
#
#  re_lu_148 (ReLU)               (None, 28, 28, 512)  0           ['add_48[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 28, 28, 128)  65664       ['re_lu_148[0][0]']
#
#  batch_normalization_155 (Batch  (None, 28, 28, 128)  512        ['conv2d_155[0][0]']
#  Normalization)
#
#  re_lu_149 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_155[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 28, 28, 128)  147584      ['re_lu_149[0][0]']
#
#  batch_normalization_156 (Batch  (None, 28, 28, 128)  512        ['conv2d_156[0][0]']
#  Normalization)
#
#  re_lu_150 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_156[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 28, 28, 512)  66048       ['re_lu_150[0][0]']
#
#  batch_normalization_157 (Batch  (None, 28, 28, 512)  2048       ['conv2d_157[0][0]']
#  Normalization)
#
#  add_49 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_157[0][0]',
#                                                                   're_lu_148[0][0]']
#
#  re_lu_151 (ReLU)               (None, 28, 28, 512)  0           ['add_49[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 28, 28, 128)  65664       ['re_lu_151[0][0]']
#
#  batch_normalization_158 (Batch  (None, 28, 28, 128)  512        ['conv2d_158[0][0]']
#  Normalization)
#
#  re_lu_152 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_158[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 28, 28, 128)  147584      ['re_lu_152[0][0]']
#
#  batch_normalization_159 (Batch  (None, 28, 28, 128)  512        ['conv2d_159[0][0]']
#  Normalization)
#
#  re_lu_153 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_159[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 28, 28, 512)  66048       ['re_lu_153[0][0]']
#
#  batch_normalization_160 (Batch  (None, 28, 28, 512)  2048       ['conv2d_160[0][0]']
#  Normalization)
#
#  add_50 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_160[0][0]',
#                                                                   're_lu_151[0][0]']
#
#  re_lu_154 (ReLU)               (None, 28, 28, 512)  0           ['add_50[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 28, 28, 128)  65664       ['re_lu_154[0][0]']
#
#  batch_normalization_161 (Batch  (None, 28, 28, 128)  512        ['conv2d_161[0][0]']
#  Normalization)
#
#  re_lu_155 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_161[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 28, 28, 128)  147584      ['re_lu_155[0][0]']
#
#  batch_normalization_162 (Batch  (None, 28, 28, 128)  512        ['conv2d_162[0][0]']
#  Normalization)
#
#  re_lu_156 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_162[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 28, 28, 512)  66048       ['re_lu_156[0][0]']
#
#  batch_normalization_163 (Batch  (None, 28, 28, 512)  2048       ['conv2d_163[0][0]']
#  Normalization)
#
#  add_51 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_163[0][0]',
#                                                                   're_lu_154[0][0]']
#
#  re_lu_157 (ReLU)               (None, 28, 28, 512)  0           ['add_51[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 28, 28, 128)  65664       ['re_lu_157[0][0]']
#
#  batch_normalization_164 (Batch  (None, 28, 28, 128)  512        ['conv2d_164[0][0]']
#  Normalization)
#
#  re_lu_158 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_164[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 28, 28, 128)  147584      ['re_lu_158[0][0]']
#
#  batch_normalization_165 (Batch  (None, 28, 28, 128)  512        ['conv2d_165[0][0]']
#  Normalization)
#
#  re_lu_159 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_165[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 28, 28, 512)  66048       ['re_lu_159[0][0]']
#
#  batch_normalization_166 (Batch  (None, 28, 28, 512)  2048       ['conv2d_166[0][0]']
#  Normalization)
#
#  add_52 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_166[0][0]',
#                                                                   're_lu_157[0][0]']
#
#  re_lu_160 (ReLU)               (None, 28, 28, 512)  0           ['add_52[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 28, 28, 128)  65664       ['re_lu_160[0][0]']
#
#  batch_normalization_167 (Batch  (None, 28, 28, 128)  512        ['conv2d_167[0][0]']
#  Normalization)
#
#  re_lu_161 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_167[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 28, 28, 128)  147584      ['re_lu_161[0][0]']
#
#  batch_normalization_168 (Batch  (None, 28, 28, 128)  512        ['conv2d_168[0][0]']
#  Normalization)
#
#  re_lu_162 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_168[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 28, 28, 512)  66048       ['re_lu_162[0][0]']
#
#  batch_normalization_169 (Batch  (None, 28, 28, 512)  2048       ['conv2d_169[0][0]']
#  Normalization)
#
#  add_53 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_169[0][0]',
#                                                                   're_lu_160[0][0]']
#
#  re_lu_163 (ReLU)               (None, 28, 28, 512)  0           ['add_53[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 28, 28, 128)  65664       ['re_lu_163[0][0]']
#
#  batch_normalization_170 (Batch  (None, 28, 28, 128)  512        ['conv2d_170[0][0]']
#  Normalization)
#
#  re_lu_164 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_170[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 28, 28, 128)  147584      ['re_lu_164[0][0]']
#
#  batch_normalization_171 (Batch  (None, 28, 28, 128)  512        ['conv2d_171[0][0]']
#  Normalization)
#
#  re_lu_165 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_171[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 28, 28, 512)  66048       ['re_lu_165[0][0]']
#
#  batch_normalization_172 (Batch  (None, 28, 28, 512)  2048       ['conv2d_172[0][0]']
#  Normalization)
#
#  add_54 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_172[0][0]',
#                                                                   're_lu_163[0][0]']
#
#  re_lu_166 (ReLU)               (None, 28, 28, 512)  0           ['add_54[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 28, 28, 256)  131328      ['re_lu_166[0][0]']
#
#  batch_normalization_173 (Batch  (None, 28, 28, 256)  1024       ['conv2d_173[0][0]']
#  Normalization)
#
#  re_lu_167 (ReLU)               (None, 28, 28, 256)  0           ['batch_normalization_173[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 14, 14, 256)  590080      ['re_lu_167[0][0]']
#
#  batch_normalization_174 (Batch  (None, 14, 14, 256)  1024       ['conv2d_174[0][0]']
#  Normalization)
#
#  re_lu_168 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_174[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 14, 14, 1024  263168      ['re_lu_168[0][0]']
#                                 )
#
#  conv2d_176 (Conv2D)            (None, 14, 14, 1024  525312      ['re_lu_166[0][0]']
#                                 )
#
#  batch_normalization_175 (Batch  (None, 14, 14, 1024  4096       ['conv2d_175[0][0]']
#  Normalization)                 )
#
#  batch_normalization_176 (Batch  (None, 14, 14, 1024  4096       ['conv2d_176[0][0]']
#  Normalization)                 )
#
#  add_55 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_175[0][0]',
#                                 )                                 'batch_normalization_176[0][0]']
#
#  re_lu_169 (ReLU)               (None, 14, 14, 1024  0           ['add_55[0][0]']
#                                 )
#
#  conv2d_177 (Conv2D)            (None, 14, 14, 256)  262400      ['re_lu_169[0][0]']
#
#  batch_normalization_177 (Batch  (None, 14, 14, 256)  1024       ['conv2d_177[0][0]']
#  Normalization)
#
#  re_lu_170 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_177[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 14, 14, 256)  590080      ['re_lu_170[0][0]']
#
#  batch_normalization_178 (Batch  (None, 14, 14, 256)  1024       ['conv2d_178[0][0]']
#  Normalization)
#
#  re_lu_171 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_178[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 14, 14, 1024  263168      ['re_lu_171[0][0]']
#                                 )
#
#  batch_normalization_179 (Batch  (None, 14, 14, 1024  4096       ['conv2d_179[0][0]']
#  Normalization)                 )
#
#  add_56 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_179[0][0]',
#                                 )                                 're_lu_169[0][0]']
#
#  re_lu_172 (ReLU)               (None, 14, 14, 1024  0           ['add_56[0][0]']
#                                 )
#
#  conv2d_180 (Conv2D)            (None, 14, 14, 256)  262400      ['re_lu_172[0][0]']
#
#  batch_normalization_180 (Batch  (None, 14, 14, 256)  1024       ['conv2d_180[0][0]']
#  Normalization)
#
#  re_lu_173 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_180[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 14, 14, 256)  590080      ['re_lu_173[0][0]']
#
#  batch_normalization_181 (Batch  (None, 14, 14, 256)  1024       ['conv2d_181[0][0]']
#  Normalization)
#
#  re_lu_174 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_181[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 14, 14, 1024  263168      ['re_lu_174[0][0]']
#                                 )
#
#  batch_normalization_182 (Batch  (None, 14, 14, 1024  4096       ['conv2d_182[0][0]']
#  Normalization)                 )
#
#  add_57 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_182[0][0]',
#                                 )                                 're_lu_172[0][0]']
#
#  re_lu_175 (ReLU)               (None, 14, 14, 1024  0           ['add_57[0][0]']
#                                 )
#
#  conv2d_183 (Conv2D)            (None, 14, 14, 256)  262400      ['re_lu_175[0][0]']
#
#  batch_normalization_183 (Batch  (None, 14, 14, 256)  1024       ['conv2d_183[0][0]']
#  Normalization)
#
#  re_lu_176 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_183[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 14, 14, 256)  590080      ['re_lu_176[0][0]']
#
#  batch_normalization_184 (Batch  (None, 14, 14, 256)  1024       ['conv2d_184[0][0]']
#  Normalization)
#
#  re_lu_177 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_184[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 14, 14, 1024  263168      ['re_lu_177[0][0]']
#                                 )
#
#  batch_normalization_185 (Batch  (None, 14, 14, 1024  4096       ['conv2d_185[0][0]']
#  Normalization)                 )
#
#  add_58 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_185[0][0]',
#                                 )                                 're_lu_175[0][0]']
#
#  re_lu_178 (ReLU)               (None, 14, 14, 1024  0           ['add_58[0][0]']
#                                 )
#
#  conv2d_186 (Conv2D)            (None, 14, 14, 256)  262400      ['re_lu_178[0][0]']
#
#  batch_normalization_186 (Batch  (None, 14, 14, 256)  1024       ['conv2d_186[0][0]']
#  Normalization)
#
#  re_lu_179 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_186[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 14, 14, 256)  590080      ['re_lu_179[0][0]']
#
#  batch_normalization_187 (Batch  (None, 14, 14, 256)  1024       ['conv2d_187[0][0]']
#  Normalization)
#
#  re_lu_180 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_187[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 14, 14, 1024  263168      ['re_lu_180[0][0]']
#                                 )
#
#  batch_normalization_188 (Batch  (None, 14, 14, 1024  4096       ['conv2d_188[0][0]']
#  Normalization)                 )
#
#  add_59 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_188[0][0]',
#                                 )                                 're_lu_178[0][0]']
#
#  re_lu_181 (ReLU)               (None, 14, 14, 1024  0           ['add_59[0][0]']
#                                 )
#
#  conv2d_189 (Conv2D)            (None, 14, 14, 256)  262400      ['re_lu_181[0][0]']
#
#  batch_normalization_189 (Batch  (None, 14, 14, 256)  1024       ['conv2d_189[0][0]']
#  Normalization)
#
#  re_lu_182 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_189[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 14, 14, 256)  590080      ['re_lu_182[0][0]']
#
#  batch_normalization_190 (Batch  (None, 14, 14, 256)  1024       ['conv2d_190[0][0]']
#  Normalization)
#
#  re_lu_183 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 14, 14, 1024  263168      ['re_lu_183[0][0]']
#                                 )
#
#  batch_normalization_191 (Batch  (None, 14, 14, 1024  4096       ['conv2d_191[0][0]']
#  Normalization)                 )
#
#  add_60 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_191[0][0]',
#                                 )                                 're_lu_181[0][0]']
#
#  re_lu_184 (ReLU)               (None, 14, 14, 1024  0           ['add_60[0][0]']
#                                 )
#
#  conv2d_192 (Conv2D)            (None, 14, 14, 256)  262400      ['re_lu_184[0][0]']
#
#  batch_normalization_192 (Batch  (None, 14, 14, 256)  1024       ['conv2d_192[0][0]']
#  Normalization)
#
#  re_lu_185 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 14, 14, 256)  590080      ['re_lu_185[0][0]']
#
#  batch_normalization_193 (Batch  (None, 14, 14, 256)  1024       ['conv2d_193[0][0]']
#  Normalization)
#
#  re_lu_186 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_193[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 14, 14, 1024  263168      ['re_lu_186[0][0]']
#                                 )
#
#  batch_normalization_194 (Batch  (None, 14, 14, 1024  4096       ['conv2d_194[0][0]']
#  Normalization)                 )
#
#  add_61 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_194[0][0]',
#                                 )                                 're_lu_184[0][0]']
#
#  re_lu_187 (ReLU)               (None, 14, 14, 1024  0           ['add_61[0][0]']
#                                 )
#
#  conv2d_195 (Conv2D)            (None, 14, 14, 256)  262400      ['re_lu_187[0][0]']
#
#  batch_normalization_195 (Batch  (None, 14, 14, 256)  1024       ['conv2d_195[0][0]']
#  Normalization)
#
# ...
#  Normalization)
#
#  re_lu_248 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_255[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 14, 14, 256)  590080      ['re_lu_248[0][0]']
#
#  batch_normalization_256 (Batch  (None, 14, 14, 256)  1024       ['conv2d_256[0][0]']
#  Normalization)
#
#  re_lu_249 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_256[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 14, 14, 1024  263168      ['re_lu_249[0][0]']
#                                 )
#
#  batch_normalization_257 (Batch  (None, 14, 14, 1024  4096       ['conv2d_257[0][0]']
#  Normalization)                 )
#
#  add_82 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_257[0][0]',
#                                 )                                 're_lu_247[0][0]']
#
#  re_lu_250 (ReLU)               (None, 14, 14, 1024  0           ['add_82[0][0]']
#                                 )
#
#  conv2d_258 (Conv2D)            (None, 14, 14, 256)  262400      ['re_lu_250[0][0]']
#
#  batch_normalization_258 (Batch  (None, 14, 14, 256)  1024       ['conv2d_258[0][0]']
#  Normalization)
#
#  re_lu_251 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_258[0][0]']
#
#  conv2d_259 (Conv2D)            (None, 14, 14, 256)  590080      ['re_lu_251[0][0]']
#
#  batch_normalization_259 (Batch  (None, 14, 14, 256)  1024       ['conv2d_259[0][0]']
#  Normalization)
#
#  re_lu_252 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_259[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 14, 14, 1024  263168      ['re_lu_252[0][0]']
#                                 )
#
#  batch_normalization_260 (Batch  (None, 14, 14, 1024  4096       ['conv2d_260[0][0]']
#  Normalization)                 )
#
#  add_83 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_260[0][0]',
#                                 )                                 're_lu_250[0][0]']
#
#  re_lu_253 (ReLU)               (None, 14, 14, 1024  0           ['add_83[0][0]']
#                                 )
#
#  conv2d_261 (Conv2D)            (None, 14, 14, 256)  262400      ['re_lu_253[0][0]']
#
#  batch_normalization_261 (Batch  (None, 14, 14, 256)  1024       ['conv2d_261[0][0]']
#  Normalization)
#
#  re_lu_254 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_261[0][0]']
#
#  conv2d_262 (Conv2D)            (None, 14, 14, 256)  590080      ['re_lu_254[0][0]']
#
#  batch_normalization_262 (Batch  (None, 14, 14, 256)  1024       ['conv2d_262[0][0]']
#  Normalization)
#
#  re_lu_255 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_262[0][0]']
#
#  conv2d_263 (Conv2D)            (None, 14, 14, 1024  263168      ['re_lu_255[0][0]']
#                                 )
#
#  batch_normalization_263 (Batch  (None, 14, 14, 1024  4096       ['conv2d_263[0][0]']
#  Normalization)                 )
#
#  add_84 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_263[0][0]',
#                                 )                                 're_lu_253[0][0]']
#
#  re_lu_256 (ReLU)               (None, 14, 14, 1024  0           ['add_84[0][0]']
#                                 )
#
#  conv2d_264 (Conv2D)            (None, 14, 14, 512)  524800      ['re_lu_256[0][0]']
#
#  batch_normalization_264 (Batch  (None, 14, 14, 512)  2048       ['conv2d_264[0][0]']
#  Normalization)
#
#  re_lu_257 (ReLU)               (None, 14, 14, 512)  0           ['batch_normalization_264[0][0]']
#
#  conv2d_265 (Conv2D)            (None, 7, 7, 512)    2359808     ['re_lu_257[0][0]']
#
#  batch_normalization_265 (Batch  (None, 7, 7, 512)   2048        ['conv2d_265[0][0]']
#  Normalization)
#
#  re_lu_258 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_265[0][0]']
#
#  conv2d_266 (Conv2D)            (None, 7, 7, 2048)   1050624     ['re_lu_258[0][0]']
#
#  conv2d_267 (Conv2D)            (None, 7, 7, 2048)   2099200     ['re_lu_256[0][0]']
#
#  batch_normalization_266 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_266[0][0]']
#  Normalization)
#
#  batch_normalization_267 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_267[0][0]']
#  Normalization)
#
#  add_85 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_266[0][0]',
#                                                                   'batch_normalization_267[0][0]']
#
#  re_lu_259 (ReLU)               (None, 7, 7, 2048)   0           ['add_85[0][0]']
#
#  conv2d_268 (Conv2D)            (None, 7, 7, 512)    1049088     ['re_lu_259[0][0]']
#
#  batch_normalization_268 (Batch  (None, 7, 7, 512)   2048        ['conv2d_268[0][0]']
#  Normalization)
#
#  re_lu_260 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_268[0][0]']
#
#  conv2d_269 (Conv2D)            (None, 7, 7, 512)    2359808     ['re_lu_260[0][0]']
#
#  batch_normalization_269 (Batch  (None, 7, 7, 512)   2048        ['conv2d_269[0][0]']
#  Normalization)
#
#  re_lu_261 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_269[0][0]']
#
#  conv2d_270 (Conv2D)            (None, 7, 7, 2048)   1050624     ['re_lu_261[0][0]']
#
#  batch_normalization_270 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_270[0][0]']
#  Normalization)
#
#  add_86 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_270[0][0]',
#                                                                   're_lu_259[0][0]']
#
#  re_lu_262 (ReLU)               (None, 7, 7, 2048)   0           ['add_86[0][0]']
#
#  conv2d_271 (Conv2D)            (None, 7, 7, 512)    1049088     ['re_lu_262[0][0]']
#
#  batch_normalization_271 (Batch  (None, 7, 7, 512)   2048        ['conv2d_271[0][0]']
#  Normalization)
#
#  re_lu_263 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_271[0][0]']
#
#  conv2d_272 (Conv2D)            (None, 7, 7, 512)    2359808     ['re_lu_263[0][0]']
#
#  batch_normalization_272 (Batch  (None, 7, 7, 512)   2048        ['conv2d_272[0][0]']
#  Normalization)
#
#  re_lu_264 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_272[0][0]']
#
#  conv2d_273 (Conv2D)            (None, 7, 7, 2048)   1050624     ['re_lu_264[0][0]']
#
#  batch_normalization_273 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_273[0][0]']
#  Normalization)
#
#  add_87 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_273[0][0]',
#                                                                   're_lu_262[0][0]']
#
#  re_lu_265 (ReLU)               (None, 7, 7, 2048)   0           ['add_87[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['re_lu_265[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 2)            4098        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 51,644,290
# Trainable params: 51,511,298
# Non-trainable params: 132,992
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("Covid_ResNet134.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.05, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 86/86 [==============================] - ETA: 0s - loss: 0.4102 - accuracy: 0.8995
# Epoch 1: val_accuracy improved from -inf to 0.67361, saving model to Covid_ResNet101.h5
# 86/86 [==============================] - 97s 838ms/step - loss: 0.4102 - accuracy: 0.8995 - val_loss: 2.1514 - val_accuracy: 0.6736 - lr: 0.0010
# Epoch 2/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.9558
# Epoch 2: val_accuracy did not improve from 0.67361
# 86/86 [==============================] - 65s 754ms/step - loss: 0.1488 - accuracy: 0.9558 - val_loss: 2.8876 - val_accuracy: 0.6736 - lr: 0.0010
# Epoch 3/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9620
# Epoch 3: val_accuracy did not improve from 0.67361
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 86/86 [==============================] - 65s 754ms/step - loss: 0.1392 - accuracy: 0.9620 - val_loss: 1.1372 - val_accuracy: 0.6736 - lr: 0.0010
# Epoch 4/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9715
# Epoch 4: val_accuracy improved from 0.67361 to 0.71528, saving model to Covid_ResNet101.h5
# 86/86 [==============================] - 68s 792ms/step - loss: 0.0960 - accuracy: 0.9715 - val_loss: 0.6761 - val_accuracy: 0.7153 - lr: 4.0000e-04
# Epoch 5/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9726
# Epoch 5: val_accuracy improved from 0.71528 to 0.95139, saving model to Covid_ResNet101.h5
# 86/86 [==============================] - 68s 795ms/step - loss: 0.0914 - accuracy: 0.9726 - val_loss: 0.1811 - val_accuracy: 0.9514 - lr: 4.0000e-04
# Epoch 6/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.9777
# Epoch 6: val_accuracy improved from 0.95139 to 0.95833, saving model to Covid_ResNet101.h5
# 86/86 [==============================] - 68s 793ms/step - loss: 0.0709 - accuracy: 0.9777 - val_loss: 0.1207 - val_accuracy: 0.9583 - lr: 4.0000e-04
# Epoch 7/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9759
# Epoch 7: val_accuracy did not improve from 0.95833
# 86/86 [==============================] - 65s 754ms/step - loss: 0.0776 - accuracy: 0.9759 - val_loss: 0.1496 - val_accuracy: 0.9444 - lr: 4.0000e-04
# Epoch 8/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9788
# Epoch 8: val_accuracy did not improve from 0.95833
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 86/86 [==============================] - 65s 757ms/step - loss: 0.0703 - accuracy: 0.9788 - val_loss: 0.1732 - val_accuracy: 0.9097 - lr: 4.0000e-04
# Epoch 9/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9905
# Epoch 9: val_accuracy improved from 0.95833 to 0.97222, saving model to Covid_ResNet101.h5
# 86/86 [==============================] - 68s 790ms/step - loss: 0.0317 - accuracy: 0.9905 - val_loss: 0.1121 - val_accuracy: 0.9722 - lr: 1.6000e-04
# Epoch 10/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9960
# Epoch 10: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 65s 759ms/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.1315 - val_accuracy: 0.9653 - lr: 1.6000e-04
# Epoch 11/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9920
# Epoch 11: val_accuracy did not improve from 0.97222
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 86/86 [==============================] - 65s 755ms/step - loss: 0.0223 - accuracy: 0.9920 - val_loss: 0.1594 - val_accuracy: 0.9653 - lr: 1.6000e-04
# Epoch 12/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9934
# Epoch 12: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 65s 755ms/step - loss: 0.0209 - accuracy: 0.9934 - val_loss: 0.1386 - val_accuracy: 0.9653 - lr: 6.4000e-05
# Epoch 13/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9978
# Epoch 13: val_accuracy did not improve from 0.97222
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 86/86 [==============================] - 66s 763ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.1325 - val_accuracy: 0.9583 - lr: 6.4000e-05
# Epoch 14/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 65s 761ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1317 - val_accuracy: 0.9722 - lr: 2.5600e-05
# Epoch 15/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 15: val_accuracy did not improve from 0.97222
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 86/86 [==============================] - 66s 763ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1290 - val_accuracy: 0.9722 - lr: 2.5600e-05
# Epoch 16/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 65s 757ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9722 - lr: 1.0240e-05
# Epoch 17/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.97222
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 86/86 [==============================] - 65s 762ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1288 - val_accuracy: 0.9722 - lr: 1.0240e-05
# Epoch 18/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9996
# Epoch 18: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 65s 758ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1296 - val_accuracy: 0.9722 - lr: 4.0960e-06
# Epoch 19/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.97222
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 86/86 [==============================] - 65s 755ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9722 - lr: 4.0960e-06
# Epoch 20/50
# 86/86 [==============================] - ETA: 0s - loss: 8.6327e-04 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 65s 755ms/step - loss: 8.6327e-04 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9722 - lr: 1.6384e-06
# Epoch 21/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 21: val_accuracy did not improve from 0.97222
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 86/86 [==============================] - 65s 756ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.1254 - val_accuracy: 0.9722 - lr: 1.6384e-06
# Epoch 22/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993
# Epoch 22: val_accuracy improved from 0.97222 to 0.97917, saving model to Covid_ResNet101.h5
# 86/86 [==============================] - 68s 793ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.1240 - val_accuracy: 0.9792 - lr: 6.5536e-07
# Epoch 23/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 23: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 756ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.1254 - val_accuracy: 0.9792 - lr: 6.5536e-07
# Epoch 24/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 24: val_accuracy did not improve from 0.97917
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 86/86 [==============================] - 65s 756ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1254 - val_accuracy: 0.9792 - lr: 6.5536e-07
# Epoch 25/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 25: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 754ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1251 - val_accuracy: 0.9792 - lr: 2.6214e-07
# Epoch 26/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 26: val_accuracy did not improve from 0.97917
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 86/86 [==============================] - 65s 755ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.1253 - val_accuracy: 0.9792 - lr: 2.6214e-07
# Epoch 27/50
# 86/86 [==============================] - ETA: 0s - loss: 9.9070e-04 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 759ms/step - loss: 9.9070e-04 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9792 - lr: 1.0486e-07
# Epoch 28/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.97917
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 86/86 [==============================] - 65s 759ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9792 - lr: 1.0486e-07
# Epoch 29/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 757ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9792 - lr: 4.1943e-08
# Epoch 30/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 30: val_accuracy did not improve from 0.97917
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 86/86 [==============================] - 65s 759ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.1249 - val_accuracy: 0.9792 - lr: 4.1943e-08
# Epoch 31/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 756ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9792 - lr: 1.6777e-08
# Epoch 32/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9996
# Epoch 32: val_accuracy did not improve from 0.97917
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.710887134886434e-09.
# 86/86 [==============================] - 65s 758ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1251 - val_accuracy: 0.9792 - lr: 1.6777e-08
# Epoch 33/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 760ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9792 - lr: 6.7109e-09
# Epoch 34/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.97917
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.6843547829003003e-09.
# 86/86 [==============================] - 65s 755ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9792 - lr: 6.7109e-09
# Epoch 35/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993
# Epoch 35: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 759ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.1256 - val_accuracy: 0.9792 - lr: 2.6844e-09
# Epoch 36/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9989
# Epoch 36: val_accuracy did not improve from 0.97917
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0737418953965518e-09.
# 86/86 [==============================] - 65s 757ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.1253 - val_accuracy: 0.9792 - lr: 2.6844e-09
# Epoch 37/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 37: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 758ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.1247 - val_accuracy: 0.9792 - lr: 1.0737e-09
# Epoch 38/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9993
# Epoch 38: val_accuracy did not improve from 0.97917
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.294967492768365e-10.
# 86/86 [==============================] - 65s 759ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.1246 - val_accuracy: 0.9792 - lr: 1.0737e-09
# Epoch 39/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9989
# Epoch 39: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 755ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.1249 - val_accuracy: 0.9792 - lr: 4.2950e-10
# Epoch 40/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9996
# Epoch 40: val_accuracy did not improve from 0.97917
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.7179869749028854e-10.
# 86/86 [==============================] - 65s 757ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.1242 - val_accuracy: 0.9792 - lr: 4.2950e-10
# Epoch 41/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 41: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 756ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1242 - val_accuracy: 0.9792 - lr: 1.7180e-10
# Epoch 42/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.97917
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.871948010633844e-11.
# 86/86 [==============================] - 65s 756ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9792 - lr: 1.7180e-10
# Epoch 43/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 759ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9792 - lr: 6.8719e-11
# Epoch 44/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 44: val_accuracy did not improve from 0.97917
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.748779259764689e-11.
# 86/86 [==============================] - 65s 759ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.1253 - val_accuracy: 0.9792 - lr: 6.8719e-11
# Epoch 45/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 45: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 761ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.1246 - val_accuracy: 0.9792 - lr: 2.7488e-11
# Epoch 46/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 46: val_accuracy did not improve from 0.97917
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.0995117316614512e-11.
# 86/86 [==============================] - 65s 757ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1238 - val_accuracy: 0.9792 - lr: 2.7488e-11
# Epoch 47/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 756ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9792 - lr: 1.0995e-11
# Epoch 48/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.97917
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 4.398046857256866e-12.
# 86/86 [==============================] - 65s 757ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9792 - lr: 1.0995e-11
# Epoch 49/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 49: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 65s 754ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1248 - val_accuracy: 0.9792 - lr: 4.3980e-12
# Epoch 50/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 50: val_accuracy did not improve from 0.97917
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.7592188122916854e-12.
# 86/86 [==============================] - 65s 754ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1245 - val_accuracy: 0.9792 - lr: 4.3980e-12

# %%
#plot the loss curve
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.ylabel('Loss',fontweight='bold')
plt.title('Loss Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('Covid_ResNet134_LossCurve',dpi=400)
plt.legend()

# %%
#plot the accuracy curve
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.ylabel('Accuracy',fontweight='bold')
plt.title('Accuracy Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('Covid_ResNet134_AccCurve',dpi=400)
plt.legend()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 10/10 [==============================] - 4s 211ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       210
#            1       0.99      0.98      0.99       110
#
#     accuracy                           0.99       320
#    macro avg       0.99      0.99      0.99       320
# weighted avg       0.99      0.99      0.99       320

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm,labels)
plt.savefig('Covid_ResNet134CM',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.5f' % accuracy_score(y_test_new, pred), 'Precision: %.5f' % precision_score(y_test_new, pred),' Recall: %.5f' % recall_score(y_test_new, pred), 
      'F1 Score: %.5f' % f1_score(y_test_new, pred), 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.99062 Precision: 0.99083  Recall: 0.98182 F1 Score: 0.98630 AUC Score: 0.98853

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
print('TP = %.5f'%TP, 'TN = %.5f'%TN, 'FP = %.5f'%FP, 'FN = %.5f'%FN)
# Out:
# TP = 108.00000 TN = 209.00000 FP = 1.00000 FN = 2.00000

# %%
recall=TP/float(TP+FN)
print(' Recall: %.5f' % recall)
precision=TP/float(TP+FP)
print(' Precision: %.5f' % precision)
# Out:
#  Recall: 0.98182
#  Precision: 0.99083

# %%
f1=(2*precision*recall)/(recall+precision)

# %%
print('F1 Score: %.5f' % f1)
# Out:
# F1 Score: 0.98630

# %%
print( 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# AUC Score: 0.98853

# %%
from sklearn.metrics import mean_squared_error
print( 'Error Rate: %.5f' % mean_squared_error(y_test_new, pred))
# Out:
# Error Rate: 0.00937

# %%
specificity=TN/float(TN+FP)
print('Specificity: %.5f' % specificity)
# Out:
# Specificity: 0.99524

# %%
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([-0.02,1.0])
plt.ylim([0.0,1.02])
plt.ylabel('Recall')
plt.xlabel('Fall-out (1-Specificity)')
plt.savefig('Covid_ResNet134AUC',dpi=400)
plt.show()

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
print('val_accuracy: {0:0.2f}%'.format(np.round((history.history['val_accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 99.06%
# Precision: 99.08%
# Recall or Sensitivity: 98.18%
# Specificity: 99.52%
# F1-score: 98.63%
# AUC-score: 98.85%
# Train acc: 99.96%
# val_accuracy: 97.92%

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score
from scipy import interp
from itertools import cycle

# %%
# Plot linewidth.
lw = 1

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test_new, pred)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_new.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(2)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(2):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= 2

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
plt.title('Receiver Operating Characteristic (ROC) Curve')
# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'cornflowerblue'])
for i, color in zip(range(2), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.02, 1.0])
plt.ylim([0.0, 1.02])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.savefig('Covid_ResNet134_ROC',dpi=400)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
