# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Covid)','Normal']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/chest_xray_dataset3200/chest_xray_dataset3200/train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 2070/2070 [00:44<00:00, 46.63it/s]
# 100%|██████████| 1130/1130 [00:24<00:00, 46.02it/s]

# %%
X_train.shape
# Out:
# (3200, 224, 224, 3)

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model

from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow

# %% [markdown]
# Model Build

# %%
from tensorflow.keras.layers import Input, DepthwiseConv2D, \
     Conv2D, BatchNormalization, ReLU, AvgPool2D, Flatten, Dense

def mobilenet_block(x, filters, strides):
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv2D(filters=filters, kernel_size=1, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

INPUT_SHAPE = 224, 224, 3

input = Input(INPUT_SHAPE)
x = Conv2D(filters=32, kernel_size=3, strides=2, padding='same')(input)
x = BatchNormalization()(x)
x = ReLU()(x)

x = mobilenet_block(x, filters=64, strides=1)

x = mobilenet_block(x, filters=128, strides=2)
x = mobilenet_block(x, filters=128, strides=1)

x = mobilenet_block(x, filters=256, strides=2)
x = mobilenet_block(x, filters=256, strides=1)

x = mobilenet_block(x, filters=512, strides=2)
for _ in range(5):
    x = mobilenet_block(x, filters=512, strides=1)
  
x = mobilenet_block(x, filters=1024, strides=2)
x = mobilenet_block(x, filters=1024, strides=1)

x = AvgPool2D(pool_size=7, strides=1)(x)
x = Flatten()(x)
output = Dense(units=2, activation='softmax')(x)

from tensorflow.keras import Model

model = Model(inputs=input, outputs=output)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_28 (Conv2D)          (None, 112, 112, 32)      896
#
#  batch_normalization_54 (Bat  (None, 112, 112, 32)     128
#  chNormalization)
#
#  re_lu_54 (ReLU)             (None, 112, 112, 32)      0
#
#  depthwise_conv2d_26 (Depthw  (None, 112, 112, 32)     320
#  iseConv2D)
#
#  batch_normalization_55 (Bat  (None, 112, 112, 32)     128
#  chNormalization)
#
#  re_lu_55 (ReLU)             (None, 112, 112, 32)      0
#
#  conv2d_29 (Conv2D)          (None, 112, 112, 64)      2112
#
#  batch_normalization_56 (Bat  (None, 112, 112, 64)     256
#  chNormalization)
#
#  re_lu_56 (ReLU)             (None, 112, 112, 64)      0
#
#  depthwise_conv2d_27 (Depthw  (None, 56, 56, 64)       640
#  iseConv2D)
#
#  batch_normalization_57 (Bat  (None, 56, 56, 64)       256
#  chNormalization)
#
#  re_lu_57 (ReLU)             (None, 56, 56, 64)        0
#
#  conv2d_30 (Conv2D)          (None, 56, 56, 128)       8320
#
#  batch_normalization_58 (Bat  (None, 56, 56, 128)      512
#  chNormalization)
#
#  re_lu_58 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_28 (Depthw  (None, 56, 56, 128)      1280
#  iseConv2D)
#
#  batch_normalization_59 (Bat  (None, 56, 56, 128)      512
#  chNormalization)
#
#  re_lu_59 (ReLU)             (None, 56, 56, 128)       0
#
#  conv2d_31 (Conv2D)          (None, 56, 56, 128)       16512
#
#  batch_normalization_60 (Bat  (None, 56, 56, 128)      512
#  chNormalization)
#
#  re_lu_60 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_29 (Depthw  (None, 28, 28, 128)      1280
#  iseConv2D)
#
#  batch_normalization_61 (Bat  (None, 28, 28, 128)      512
#  chNormalization)
#
#  re_lu_61 (ReLU)             (None, 28, 28, 128)       0
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 256)       33024
#
#  batch_normalization_62 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  re_lu_62 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_30 (Depthw  (None, 28, 28, 256)      2560
#  iseConv2D)
#
#  batch_normalization_63 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  re_lu_63 (ReLU)             (None, 28, 28, 256)       0
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 256)       65792
#
#  batch_normalization_64 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  re_lu_64 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_31 (Depthw  (None, 14, 14, 256)      2560
#  iseConv2D)
#
#  batch_normalization_65 (Bat  (None, 14, 14, 256)      1024
#  chNormalization)
#
#  re_lu_65 (ReLU)             (None, 14, 14, 256)       0
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 512)       131584
#
#  batch_normalization_66 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_66 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_32 (Depthw  (None, 14, 14, 512)      5120
#  iseConv2D)
#
#  batch_normalization_67 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_67 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 512)       262656
#
#  batch_normalization_68 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_68 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_33 (Depthw  (None, 14, 14, 512)      5120
#  iseConv2D)
#
#  batch_normalization_69 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_69 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_36 (Conv2D)          (None, 14, 14, 512)       262656
#
#  batch_normalization_70 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_70 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_34 (Depthw  (None, 14, 14, 512)      5120
#  iseConv2D)
#
#  batch_normalization_71 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_71 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_37 (Conv2D)          (None, 14, 14, 512)       262656
#
#  batch_normalization_72 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_72 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_35 (Depthw  (None, 14, 14, 512)      5120
#  iseConv2D)
#
#  batch_normalization_73 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_73 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_38 (Conv2D)          (None, 14, 14, 512)       262656
#
#  batch_normalization_74 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_74 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_36 (Depthw  (None, 14, 14, 512)      5120
#  iseConv2D)
#
#  batch_normalization_75 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_75 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 512)       262656
#
#  batch_normalization_76 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  re_lu_76 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_37 (Depthw  (None, 7, 7, 512)        5120
#  iseConv2D)
#
#  batch_normalization_77 (Bat  (None, 7, 7, 512)        2048
#  chNormalization)
#
#  re_lu_77 (ReLU)             (None, 7, 7, 512)         0
#
#  conv2d_40 (Conv2D)          (None, 7, 7, 1024)        525312
#
#  batch_normalization_78 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  re_lu_78 (ReLU)             (None, 7, 7, 1024)        0
#
#  depthwise_conv2d_38 (Depthw  (None, 7, 7, 1024)       10240
#  iseConv2D)
#
#  batch_normalization_79 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  re_lu_79 (ReLU)             (None, 7, 7, 1024)        0
#
#  conv2d_41 (Conv2D)          (None, 7, 7, 1024)        1049600
#
#  batch_normalization_80 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  re_lu_80 (ReLU)             (None, 7, 7, 1024)        0
#
#  average_pooling2d_2 (Averag  (None, 1, 1, 1024)       0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 2)                 2050
#
# =================================================================
# Total params: 3,241,858
# Trainable params: 3,219,970
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("MobileNet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.05, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 86/86 [==============================] - ETA: 0s - loss: 0.2129 - accuracy: 0.9346
# Epoch 1: val_accuracy improved from -inf to 0.67361, saving model to MobileNet.h5
# 86/86 [==============================] - 30s 205ms/step - loss: 0.2129 - accuracy: 0.9346 - val_loss: 0.9145 - val_accuracy: 0.6736 - lr: 0.0010
# Epoch 2/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9638
# Epoch 2: val_accuracy did not improve from 0.67361
# 86/86 [==============================] - 16s 189ms/step - loss: 0.1265 - accuracy: 0.9638 - val_loss: 1.5173 - val_accuracy: 0.6736 - lr: 0.0010
# Epoch 3/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9631
# Epoch 3: val_accuracy did not improve from 0.67361
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 86/86 [==============================] - 17s 192ms/step - loss: 0.1126 - accuracy: 0.9631 - val_loss: 2.1251 - val_accuracy: 0.6736 - lr: 0.0010
# Epoch 4/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9762
# Epoch 4: val_accuracy did not improve from 0.67361
# 86/86 [==============================] - 16s 187ms/step - loss: 0.0740 - accuracy: 0.9762 - val_loss: 2.1851 - val_accuracy: 0.6736 - lr: 4.0000e-04
# Epoch 5/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9898
# Epoch 5: val_accuracy did not improve from 0.67361
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 86/86 [==============================] - 16s 189ms/step - loss: 0.0348 - accuracy: 0.9898 - val_loss: 2.8196 - val_accuracy: 0.6736 - lr: 4.0000e-04
# Epoch 6/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9963
# Epoch 6: val_accuracy did not improve from 0.67361
# 86/86 [==============================] - 17s 198ms/step - loss: 0.0131 - accuracy: 0.9963 - val_loss: 3.6851 - val_accuracy: 0.6736 - lr: 1.6000e-04
# Epoch 7/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9978
# Epoch 7: val_accuracy did not improve from 0.67361
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 86/86 [==============================] - 16s 191ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 4.4349 - val_accuracy: 0.6736 - lr: 1.6000e-04
# Epoch 8/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0038 - accuracy:
ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1677 - val_accuracy: 0.9722 - lr: 4.2950e-10
# Epoch 40/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 16s 192ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9722 - lr: 1.7180e-10
# Epoch 41/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 41: val_accuracy did not improve from 0.97222
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.871948010633844e-11.
# 86/86 [==============================] - 17s 193ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1681 - val_accuracy: 0.9722 - lr: 1.7180e-10
# Epoch 42/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 42: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 16s 190ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1679 - val_accuracy: 0.9722 - lr: 6.8719e-11
# Epoch 43/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9996
# Epoch 43: val_accuracy did not improve from 0.97222
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 2.748779259764689e-11.
# 86/86 [==============================] - 16s 190ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1674 - val_accuracy: 0.9722 - lr: 6.8719e-11
# Epoch 44/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9993
# Epoch 44: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 16s 191ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1673 - val_accuracy: 0.9722 - lr: 2.7488e-11
# Epoch 45/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.97222
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.0995117316614512e-11.
# 86/86 [==============================] - 17s 192ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9722 - lr: 2.7488e-11
# Epoch 46/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996
# Epoch 46: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 17s 194ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1672 - val_accuracy: 0.9722 - lr: 1.0995e-11
# Epoch 47/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.97222
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 4.398046857256866e-12.
# 86/86 [==============================] - 16s 190ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.9722 - lr: 1.0995e-11
# Epoch 48/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996
# Epoch 48: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 16s 191ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.1667 - val_accuracy: 0.9722 - lr: 4.3980e-12
# Epoch 49/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.97222
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.7592188122916854e-12.
# 86/86 [==============================] - 16s 191ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1667 - val_accuracy: 0.9722 - lr: 4.3980e-12
# Epoch 50/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 17s 193ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1666 - val_accuracy: 0.9722 - lr: 1.7592e-12

# %%
#plot the accuracy curve
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.ylabel('Accuracy',fontweight='bold')
plt.title('Accuracy Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('MobileNet_AccCurve',dpi=400)
plt.legend()

# %%
#plot the loss curve
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.ylabel('Loss',fontweight='bold')
plt.title('Loss Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('MobileNet_LossCurve',dpi=400)
plt.legend()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 10/10 [==============================] - 1s 36ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       210
#            1       0.96      0.98      0.97       110
#
#     accuracy                           0.98       320
#    macro avg       0.98      0.98      0.98       320
# weighted avg       0.98      0.98      0.98       320

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm,labels)
plt.savefig('MobileNetCM',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.5f' % accuracy_score(y_test_new, pred), 'Precision: %.5f' % precision_score(y_test_new, pred),' Recall: %.5f' % recall_score(y_test_new, pred), 
      'F1 Score: %.5f' % f1_score(y_test_new, pred), 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.98125 Precision: 0.96429  Recall: 0.98182 F1 Score: 0.97297 AUC Score: 0.98139

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
print('TP = %.5f'%TP, 'TN = %.5f'%TN, 'FP = %.5f'%FP, 'FN = %.5f'%FN)
# Out:
# TP = 108.00000 TN = 206.00000 FP = 4.00000 FN = 2.00000

# %%
specificity=TN/float(TN+FP)
print('Specificity: %.5f' % specificity)
# Out:
# Specificity: 0.98095

# %%
recall=TP/float(TP+FN)
print(' Recall: %.5f' % recall)
precision=TP/float(TP+FP)
print(' Precision: %.5f' % precision)
# Out:
#  Recall: 0.98182
#  Precision: 0.96429

# %%
f1=(2*precision*recall)/(recall+precision)
print('F1 Score: %.5f' % f1)
# Out:
# F1 Score: 0.97297

# %%
print( 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# AUC Score: 0.98139

# %%
from sklearn.metrics import mean_squared_error
print( 'Error Rate: %.5f' % mean_squared_error(y_test_new, pred))
# Out:
# Error Rate: 0.01875

# %%
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.ylabel('Recall')
plt.xlabel('Fall-out (1-Specificity)')
plt.savefig('MobileNetAUC',dpi=400)
plt.show()

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
print('val_accuracy: {0:0.2f}%'.format(np.round((history.history['val_accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 98.12%
# Precision: 96.43%
# Recall or Sensitivity: 98.18%
# Specificity: 98.10%
# F1-score: 97.30%
# AUC-score: 98.14%
# Train acc: 100.00%
# val_accuracy: 97.22%

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score
from scipy import interp
from itertools import cycle

# %%
# Plot linewidth.
lw = 1

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test_new, pred)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_new.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(2)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(2):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= 2

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
plt.title('Receiver Operating Characteristic (ROC) Curve')
# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'cornflowerblue'])
for i, color in zip(range(2), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.savefig('MobileNet_ROC',dpi=400)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
