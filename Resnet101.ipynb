# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Covid)','Normal']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/chest_xray_dataset3200/train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 2070/2070 [00:48<00:00, 42.83it/s]
# 100%|██████████| 1130/1130 [00:26<00:00, 42.51it/s]

# %%
X_train.shape
# Out:
# (3200, 224, 224, 3)

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import cv2
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import keras
from keras.models import Sequential, Model,load_model
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping,ModelCheckpoint
from google.colab.patches import cv2_imshow
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform

# %% [markdown]
# Model Build

# %%
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D, BatchNormalization, ReLU, Add
from tensorflow.keras.layers import MaxPool2D, GlobalAvgPool2D, Dense
 
def conv_batchnorm_relu(x, filters, kernel_size, strides):
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=strides,
               padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x
 
def identity_block(tensor, filters):
    x = conv_batchnorm_relu(tensor, filters=filters, kernel_size=1, strides=1)
    x = conv_batchnorm_relu(x, filters=filters, kernel_size=3, strides=1)
    x = Conv2D(filters=4*filters, kernel_size=1, strides=1)(x)  # notice: filters=4*filters
    x = BatchNormalization()(x)
 
    x = Add()([x, tensor])
    x = ReLU()(x)
    return x
 
 
def projection_block(tensor, filters, strides):
    # left stream
    x = conv_batchnorm_relu(tensor, filters=filters, kernel_size=1, strides=1)
    x = conv_batchnorm_relu(x, filters=filters, kernel_size=3, strides=strides)
    x = Conv2D(filters=4*filters, kernel_size=1, strides=1)(x)  # notice: filters=4*filters
    x = BatchNormalization()(x)
 
    # right stream
    shortcut = Conv2D(filters=4*filters, kernel_size=1, strides=strides)(tensor)  # notice: filters=4*filters
    shortcut = BatchNormalization()(shortcut)
 
    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x
 
 
def resnet_block(x, filters, reps, strides):
    x = projection_block(x, filters=filters, strides=strides)
    for _ in range(reps-1):  # the -1 is because the first block was a Conv one
        x = identity_block(x, filters=filters)
    return x
 
 
input = Input(shape=(224, 224, 3))
 
x = conv_batchnorm_relu(input, filters=64, kernel_size=7, strides=2)  # [3]: 7x7, 64, strides 2
x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)  # [3]: 3x3 max mool, strides 2
 
x = resnet_block(x, filters=64, reps=3, strides=1)
x = resnet_block(x, filters=128, reps=4, strides=2)  # s=2 ([2]: conv3_1)
x = resnet_block(x, filters=256, reps=23, strides=2)  # s=2 ([2]: conv4_1)
x = resnet_block(x, filters=512, reps=3, strides=2)  # s=2 ([2]: conv5_1)
 
x = GlobalAvgPool2D()(x)  # [3]: average pool *it is not written any pool size so we use Global
 
output = Dense(2, activation='softmax')(x)  # [3]: 1000-d fc, softmax
 
from tensorflow.keras import Model
 
model = Model(input, output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['re_lu[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 64)   36928       ['re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 56, 56, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 256)  16640       ['re_lu_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 256)  16640       ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 56, 56, 256)  0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 56, 56, 256)  0           ['add[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 64)   16448       ['re_lu_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 56, 56, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 64)   36928       ['re_lu_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 56, 56, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 256)  16640       ['re_lu_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 56, 56, 256)  0           ['batch_normalization_7[0][0]',
#                                                                   're_lu_3[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 56, 56, 256)  0           ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 64)   16448       ['re_lu_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 56, 56, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 56, 64)   36928       ['re_lu_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 56, 56, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 256)  16640       ['re_lu_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 56, 56, 256)  0           ['batch_normalization_10[0][0]',
#                                                                   're_lu_6[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 56, 56, 256)  0           ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 128)  32896       ['re_lu_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 56, 56, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 56, 56, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  147584      ['re_lu_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 512)  66048       ['re_lu_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 512)  131584      ['re_lu_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_14[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_13[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  re_lu_12 (ReLU)                (None, 28, 28, 512)  0           ['add_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 128)  65664       ['re_lu_12[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 128)  147584      ['re_lu_13[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 512)  66048       ['re_lu_14[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_17[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_17[0][0]',
#                                                                   're_lu_12[0][0]']
#
#  re_lu_15 (ReLU)                (None, 28, 28, 512)  0           ['add_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 128)  65664       ['re_lu_15[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 128)  147584      ['re_lu_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 512)  66048       ['re_lu_17[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_20[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_20[0][0]',
#                                                                   're_lu_15[0][0]']
#
#  re_lu_18 (ReLU)                (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 28, 128)  65664       ['re_lu_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 128)  512        ['conv2d_21[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 28, 28, 128)  147584      ['re_lu_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 512)  66048       ['re_lu_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_23[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_23[0][0]',
#                                                                   're_lu_18[0][0]']
#
#  re_lu_21 (ReLU)                (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 256)  131328      ['re_lu_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 28, 28, 256)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_23[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 1024  525312      ['re_lu_21[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  add_7 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_26[0][0]',
#                                 )                                 'batch_normalization_27[0][0]']
#
#  re_lu_24 (ReLU)                (None, 14, 14, 1024  0           ['add_7[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_24[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_25[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_26[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_30[0][0]']
#  ormalization)                  )
#
#  add_8 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_30[0][0]',
#                                 )                                 're_lu_24[0][0]']
#
#  re_lu_27 (ReLU)                (None, 14, 14, 1024  0           ['add_8[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_27[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_29[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_33[0][0]',
#                                 )                                 're_lu_27[0][0]']
#
#  re_lu_30 (ReLU)                (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_30[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_34[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_31[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_35[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_32[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_36[0][0]',
#                                 )                                 're_lu_30[0][0]']
#
#  re_lu_33 (ReLU)                (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_33[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_37[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_34[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_38[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_35[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_39[0][0]',
#                                 )                                 're_lu_33[0][0]']
#
#  re_lu_36 (ReLU)                (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_36[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_40[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_37[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_41[0][0]']
#  ormalization)
#
#  re_lu_38 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_38[0][0]']
#                                 )
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_42[0][0]']
#  ormalization)                  )
#
#  add_12 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_42[0][0]',
#                                 )                                 're_lu_36[0][0]']
#
#  re_lu_39 (ReLU)                (None, 14, 14, 1024  0           ['add_12[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_39[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_43[0][0]']
#  ormalization)
#
#  re_lu_40 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_40[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_44[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_41[0][0]']
#                                 )
#
#  batch_normalization_45 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_45[0][0]']
#  ormalization)                  )
#
#  add_13 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_45[0][0]',
#                                 )                                 're_lu_39[0][0]']
#
#  re_lu_42 (ReLU)                (None, 14, 14, 1024  0           ['add_13[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_42[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_46[0][0]']
#  ormalization)
#
#  re_lu_43 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_43[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_47[0][0]']
#  ormalization)
#
#  re_lu_44 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_44[0][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_48[0][0]']
#  ormalization)                  )
#
#  add_14 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_48[0][0]',
#                                 )                                 're_lu_42[0][0]']
#
#  re_lu_45 (ReLU)                (None, 14, 14, 1024  0           ['add_14[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_45[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_49[0][0]']
#  ormalization)
#
#  re_lu_46 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_46[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_50[0][0]']
#  ormalization)
#
#  re_lu_47 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_47[0][0]']
#                                 )
#
#  batch_normalization_51 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_51[0][0]']
#  ormalization)                  )
#
#  add_15 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_51[0][0]',
#                                 )                                 're_lu_45[0][0]']
#
#  re_lu_48 (ReLU)                (None, 14, 14, 1024  0           ['add_15[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_48[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_52[0][0]']
#  ormalization)
#
#  re_lu_49 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_49[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_53[0][0]']
#  ormalization)
#
#  re_lu_50 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_50[0][0]']
#                                 )
#
#  batch_normalization_54 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  add_16 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_54[0][0]',
#                                 )                                 're_lu_48[0][0]']
#
#  re_lu_51 (ReLU)                (None, 14, 14, 1024  0           ['add_16[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_51[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_55[0][0]']
#  ormalization)
#
#  re_lu_52 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_52[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_56[0][0]']
#  ormalization)
#
#  re_lu_53 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_53[0][0]']
#                                 )
#
#  batch_normalization_57 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  add_17 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_57[0][0]',
#                                 )                                 're_lu_51[0][0]']
#
# ...
#  ormalization)
#
#  re_lu_82 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_85[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_82[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_86[0][0]']
#  ormalization)
#
#  re_lu_83 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_83[0][0]']
#                                 )
#
#  batch_normalization_87 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_87[0][0]']
#  ormalization)                  )
#
#  add_27 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_87[0][0]',
#                                 )                                 're_lu_81[0][0]']
#
#  re_lu_84 (ReLU)                (None, 14, 14, 1024  0           ['add_27[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_84[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_88[0][0]']
#  ormalization)
#
#  re_lu_85 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_88[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_85[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_89[0][0]']
#  ormalization)
#
#  re_lu_86 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_89[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_86[0][0]']
#                                 )
#
#  batch_normalization_90 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_90[0][0]']
#  ormalization)                  )
#
#  add_28 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_90[0][0]',
#                                 )                                 're_lu_84[0][0]']
#
#  re_lu_87 (ReLU)                (None, 14, 14, 1024  0           ['add_28[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 14, 14, 256)  262400      ['re_lu_87[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_91[0][0]']
#  ormalization)
#
#  re_lu_88 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_91[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 14, 14, 256)  590080      ['re_lu_88[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_92[0][0]']
#  ormalization)
#
#  re_lu_89 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 14, 14, 1024  263168      ['re_lu_89[0][0]']
#                                 )
#
#  batch_normalization_93 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_93[0][0]']
#  ormalization)                  )
#
#  add_29 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_93[0][0]',
#                                 )                                 're_lu_87[0][0]']
#
#  re_lu_90 (ReLU)                (None, 14, 14, 1024  0           ['add_29[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 14, 14, 512)  524800      ['re_lu_90[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_94[0][0]']
#  ormalization)
#
#  re_lu_91 (ReLU)                (None, 14, 14, 512)  0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 7, 7, 512)    2359808     ['re_lu_91[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_95[0][0]']
#  ormalization)
#
#  re_lu_92 (ReLU)                (None, 7, 7, 512)    0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 7, 7, 2048)   1050624     ['re_lu_92[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 7, 7, 2048)   2099200     ['re_lu_90[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_96[0][0]']
#  ormalization)
#
#  batch_normalization_97 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_97[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_96[0][0]',
#                                                                   'batch_normalization_97[0][0]']
#
#  re_lu_93 (ReLU)                (None, 7, 7, 2048)   0           ['add_30[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 7, 7, 512)    1049088     ['re_lu_93[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_98[0][0]']
#  ormalization)
#
#  re_lu_94 (ReLU)                (None, 7, 7, 512)    0           ['batch_normalization_98[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 7, 7, 512)    2359808     ['re_lu_94[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_99[0][0]']
#  ormalization)
#
#  re_lu_95 (ReLU)                (None, 7, 7, 512)    0           ['batch_normalization_99[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 7, 7, 2048)   1050624     ['re_lu_95[0][0]']
#
#  batch_normalization_100 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_100[0][0]']
#  Normalization)
#
#  add_31 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_100[0][0]',
#                                                                   're_lu_93[0][0]']
#
#  re_lu_96 (ReLU)                (None, 7, 7, 2048)   0           ['add_31[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 7, 7, 512)    1049088     ['re_lu_96[0][0]']
#
#  batch_normalization_101 (Batch  (None, 7, 7, 512)   2048        ['conv2d_101[0][0]']
#  Normalization)
#
#  re_lu_97 (ReLU)                (None, 7, 7, 512)    0           ['batch_normalization_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 7, 7, 512)    2359808     ['re_lu_97[0][0]']
#
#  batch_normalization_102 (Batch  (None, 7, 7, 512)   2048        ['conv2d_102[0][0]']
#  Normalization)
#
#  re_lu_98 (ReLU)                (None, 7, 7, 512)    0           ['batch_normalization_102[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 7, 7, 2048)   1050624     ['re_lu_98[0][0]']
#
#  batch_normalization_103 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_103[0][0]']
#  Normalization)
#
#  add_32 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_103[0][0]',
#                                                                   're_lu_96[0][0]']
#
#  re_lu_99 (ReLU)                (None, 7, 7, 2048)   0           ['add_32[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['re_lu_99[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            4098        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 42,662,274
# Trainable params: 42,556,930
# Non-trainable params: 105,344
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("Covid_ResNet121.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.05, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 86/86 [==============================] - ETA: 0s - loss: 0.3276 - accuracy: 0.9232
# Epoch 1: val_accuracy improved from -inf to 0.67361, saving model to Covid_ResNet121.h5
# 86/86 [==============================] - 80s 619ms/step - loss: 0.3276 - accuracy: 0.9232 - val_loss: 1.9361 - val_accuracy: 0.6736 - lr: 0.0010
# Epoch 2/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9616
# Epoch 2: val_accuracy did not improve from 0.67361
# 86/86 [==============================] - 49s 571ms/step - loss: 0.1286 - accuracy: 0.9616 - val_loss: 1.5096 - val_accuracy: 0.6736 - lr: 0.0010
# Epoch 3/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9671
# Epoch 3: val_accuracy improved from 0.67361 to 0.72917, saving model to Covid_ResNet121.h5
# 86/86 [==============================] - 51s 596ms/step - loss: 0.1167 - accuracy: 0.9671 - val_loss: 0.5116 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 4/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9730
# Epoch 4: val_accuracy improved from 0.72917 to 0.74306, saving model to Covid_ResNet121.h5
# 86/86 [==============================] - 52s 605ms/step - loss: 0.0998 - accuracy: 0.9730 - val_loss: 0.4828 - val_accuracy: 0.7431 - lr: 0.0010
# Epoch 5/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9748
# Epoch 5: val_accuracy improved from 0.74306 to 0.86111, saving model to Covid_ResNet121.h5
# 86/86 [==============================] - 51s 596ms/step - loss: 0.0909 - accuracy: 0.9748 - val_loss: 0.3316 - val_accuracy: 0.8611 - lr: 0.0010
# Epoch 6/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0864 - accuracy: 0.9722
# Epoch 6: val_accuracy did not improve from 0.86111
# 86/86 [==============================] - 49s 573ms/step - loss: 0.0864 - accuracy: 0.9722 - val_loss: 1.6124 - val_accuracy: 0.8542 - lr: 0.0010
# Epoch 7/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9726
# Epoch 7: val_accuracy did not improve from 0.86111
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0872 - accuracy: 0.9726 - val_loss: 23.6203 - val_accuracy: 0.3403 - lr: 0.0010
# Epoch 8/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9846
# Epoch 8: val_accuracy improved from 0.86111 to 0.96528, saving model to Covid_ResNet121.h5
# 86/86 [==============================] - 51s 598ms/step - loss: 0.0465 - accuracy: 0.9846 - val_loss: 0.1617 - val_accuracy: 0.9653 - lr: 4.0000e-04
# Epoch 9/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9901
# Epoch 9: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 568ms/step - loss: 0.0341 - accuracy: 0.9901 - val_loss: 0.1180 - val_accuracy: 0.9583 - lr: 4.0000e-04
# Epoch 10/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9865
# Epoch 10: val_accuracy did not improve from 0.96528
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 86/86 [==============================] - 49s 573ms/step - loss: 0.0400 - accuracy: 0.9865 - val_loss: 0.1681 - val_accuracy: 0.9653 - lr: 4.0000e-04
# Epoch 11/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9931
# Epoch 11: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 573ms/step - loss: 0.0221 - accuracy: 0.9931 - val_loss: 0.1255 - val_accuracy: 0.9583 - lr: 1.6000e-04
# Epoch 12/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9974
# Epoch 12: val_accuracy did not improve from 0.96528
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.1236 - val_accuracy: 0.9583 - lr: 1.6000e-04
# Epoch 13/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9985
# Epoch 13: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.1559 - val_accuracy: 0.9583 - lr: 6.4000e-05
# Epoch 14/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9993
# Epoch 14: val_accuracy did not improve from 0.96528
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 86/86 [==============================] - 49s 575ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1580 - val_accuracy: 0.9514 - lr: 6.4000e-05
# Epoch 15/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993
# Epoch 15: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.1587 - val_accuracy: 0.9514 - lr: 2.5600e-05
# Epoch 16/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9996
# Epoch 16: val_accuracy did not improve from 0.96528
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 86/86 [==============================] - 49s 568ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.1604 - val_accuracy: 0.9444 - lr: 2.5600e-05
# Epoch 17/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 17: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 567ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.1597 - val_accuracy: 0.9444 - lr: 1.0240e-05
# Epoch 18/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.96528
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 86/86 [==============================] - 49s 573ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1610 - val_accuracy: 0.9444 - lr: 1.0240e-05
# Epoch 19/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 19: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 573ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.1620 - val_accuracy: 0.9444 - lr: 4.0960e-06
# Epoch 20/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 20: val_accuracy did not improve from 0.96528
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 86/86 [==============================] - 49s 569ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1616 - val_accuracy: 0.9444 - lr: 4.0960e-06
# Epoch 21/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9996
# Epoch 21: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 573ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.1617 - val_accuracy: 0.9444 - lr: 1.6384e-06
# Epoch 22/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.96528
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.9444 - lr: 1.6384e-06
# Epoch 23/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9989
# Epoch 23: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.1615 - val_accuracy: 0.9444 - lr: 6.5536e-07
# Epoch 24/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.96528
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 86/86 [==============================] - 49s 568ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.9444 - lr: 6.5536e-07
# Epoch 25/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 568ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1623 - val_accuracy: 0.9444 - lr: 2.6214e-07
# Epoch 26/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 26: val_accuracy did not improve from 0.96528
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 86/86 [==============================] - 49s 567ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.1608 - val_accuracy: 0.9444 - lr: 2.6214e-07
# Epoch 27/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9444 - lr: 1.0486e-07
# Epoch 28/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 28: val_accuracy did not improve from 0.96528
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 86/86 [==============================] - 49s 567ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1614 - val_accuracy: 0.9444 - lr: 1.0486e-07
# Epoch 29/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 568ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9444 - lr: 4.1943e-08
# Epoch 30/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9996
# Epoch 30: val_accuracy did not improve from 0.96528
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0039 - accuracy: 0.9996 - val_loss: 0.1622 - val_accuracy: 0.9444 - lr: 4.1943e-08
# Epoch 31/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 575ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1615 - val_accuracy: 0.9444 - lr: 1.6777e-08
# Epoch 32/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.96528
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.710887134886434e-09.
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1622 - val_accuracy: 0.9444 - lr: 1.6777e-08
# Epoch 33/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 33: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 575ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1613 - val_accuracy: 0.9444 - lr: 6.7109e-09
# Epoch 34/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 34: val_accuracy did not improve from 0.96528
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.6843547829003003e-09.
# 86/86 [==============================] - 49s 569ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1624 - val_accuracy: 0.9444 - lr: 6.7109e-09
# Epoch 35/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 568ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1618 - val_accuracy: 0.9444 - lr: 2.6844e-09
# Epoch 36/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 36: val_accuracy did not improve from 0.96528
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0737418953965518e-09.
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1625 - val_accuracy: 0.9444 - lr: 2.6844e-09
# Epoch 37/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 569ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9444 - lr: 1.0737e-09
# Epoch 38/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9993
# Epoch 38: val_accuracy did not improve from 0.96528
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.294967492768365e-10.
# 86/86 [==============================] - 49s 569ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.1626 - val_accuracy: 0.9444 - lr: 1.0737e-09
# Epoch 39/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 575ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9444 - lr: 4.2950e-10
# Epoch 40/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 40: val_accuracy did not improve from 0.96528
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.7179869749028854e-10.
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1628 - val_accuracy: 0.9444 - lr: 4.2950e-10
# Epoch 41/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 41: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1620 - val_accuracy: 0.9444 - lr: 1.7180e-10
# Epoch 42/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.96528
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.871948010633844e-11.
# 86/86 [==============================] - 49s 569ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.9444 - lr: 1.7180e-10
# Epoch 43/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 568ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9444 - lr: 6.8719e-11
# Epoch 44/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 44: val_accuracy did not improve from 0.96528
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.748779259764689e-11.
# 86/86 [==============================] - 49s 568ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.1617 - val_accuracy: 0.9444 - lr: 6.8719e-11
# Epoch 45/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1621 - val_accuracy: 0.9444 - lr: 2.7488e-11
# Epoch 46/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 46: val_accuracy did not improve from 0.96528
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.0995117316614512e-11.
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1630 - val_accuracy: 0.9444 - lr: 2.7488e-11
# Epoch 47/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9996
# Epoch 47: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 574ms/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 0.1619 - val_accuracy: 0.9444 - lr: 1.0995e-11
# Epoch 48/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.96528
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 4.398046857256866e-12.
# 86/86 [==============================] - 49s 575ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1622 - val_accuracy: 0.9444 - lr: 1.0995e-11
# Epoch 49/50
# 86/86 [==============================] - ETA: 0s - loss: 9.3853e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 49s 575ms/step - loss: 9.3853e-04 - accuracy: 1.0000 - val_loss: 0.1623 - val_accuracy: 0.9444 - lr: 4.3980e-12
# Epoch 50/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 50: val_accuracy did not improve from 0.96528
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.7592188122916854e-12.
# 86/86 [==============================] - 49s 569ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1604 - val_accuracy: 0.9444 - lr: 4.3980e-12

# %%
#plot the loss curve
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.ylabel('Loss',fontweight='bold')
plt.title('Loss Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('Covid_ResNet121_LossCurve',dpi=400)
plt.legend()

# %%
#plot the accuracy curve
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.ylabel('Accuracy',fontweight='bold')
plt.title('Accuracy Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('Covid_ResNet121_AccCurve',dpi=400)
plt.legend()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 10/10 [==============================] - 3s 163ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       210
#            1       0.99      0.99      0.99       110
#
#     accuracy                           0.99       320
#    macro avg       0.99      0.99      0.99       320
# weighted avg       0.99      0.99      0.99       320

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm,labels)
plt.savefig('Covid_ResNet121CM',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.5f' % accuracy_score(y_test_new, pred), 'Precision: %.5f' % precision_score(y_test_new, pred),' Recall: %.5f' % recall_score(y_test_new, pred), 
      'F1 Score: %.5f' % f1_score(y_test_new, pred), 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.99375 Precision: 0.99091  Recall: 0.99091 F1 Score: 0.99091 AUC Score: 0.99307

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
print('TP = %.5f'%TP, 'TN = %.5f'%TN, 'FP = %.5f'%FP, 'FN = %.5f'%FN)
# Out:
# TP = 109.00000 TN = 209.00000 FP = 1.00000 FN = 1.00000

# %%
recall=TP/float(TP+FN)
print(' Recall: %.5f' % recall)
precision=TP/float(TP+FP)
print(' Precision: %.5f' % precision)
# Out:
#  Recall: 0.99091
#  Precision: 0.99091

# %%
f1=(2*precision*recall)/(recall+precision)

# %%
print('F1 Score: %.5f' % f1)
# Out:
# F1 Score: 0.99091

# %%
print( 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# AUC Score: 0.99307

# %%
from sklearn.metrics import mean_squared_error
print( 'Error Rate: %.5f' % mean_squared_error(y_test_new, pred))
# Out:
# Error Rate: 0.00625

# %%
specificity=TN/float(TN+FP)
print('Specificity: %.5f' % specificity)
# Out:
# Specificity: 0.99524

# %%
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.ylabel('Recall')
plt.xlabel('Fall-out (1-Specificity)')
plt.savefig('Covid_ResNet121AUC',dpi=400)

plt.show()

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
print('val_accuracy: {0:0.2f}%'.format(np.round((history.history['val_accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 99.38%
# Precision: 99.09%
# Recall or Sensitivity: 99.09%
# Specificity: 99.52%
# F1-score: 99.09%
# AUC-score: 99.31%
# Train acc: 99.96%
# val_accuracy: 94.44%

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score
from scipy import interp
from itertools import cycle

# %%
# Plot linewidth.
lw = 1

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test_new, pred)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_new.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(2)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(2):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= 2

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
plt.title('Receiver Operating Characteristic (ROC) Curve')
# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'cornflowerblue'])
for i, color in zip(range(2), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.savefig('Covid_ResNet101_ROC',dpi=400)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
