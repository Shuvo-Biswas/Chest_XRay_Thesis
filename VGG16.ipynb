# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Covid)','Normal']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/chest_xray_dataset3200/train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 2070/2070 [00:45<00:00, 45.33it/s]
# 100%|██████████| 1130/1130 [00:21<00:00, 52.51it/s]

# %%
X_train.shape
# Out:
# (3200, 224, 224, 3)

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model

from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow

# %%
from tensorflow.keras.layers import Input, Conv2D, \
     MaxPool2D, Flatten, Dense

input = Input(shape=(224, 224, 3))

x = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(input)
x = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x)
x = MaxPool2D(pool_size=2, strides=2, padding='same')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(x)
x = Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(x)
x = MaxPool2D(pool_size=2, strides=2, padding='same')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu')(x)
x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu')(x)
x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu')(x)
x = MaxPool2D(pool_size=2, strides=2, padding='same')(x)

x = Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(x)
x = Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(x)
x = Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(x)
x = MaxPool2D(pool_size=2, strides=2, padding='same')(x)

x = Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(x)
x = Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(x)
x = Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(x)
x = MaxPool2D(pool_size=2, strides=2, padding='same')(x)

x = Flatten()(x)
x = Dense(units=4096, activation='relu')(x)
x = Dense(units=4096, activation='relu')(x)
x = Dense(units=2, activation='softmax')(x)

# %%
# Create model.
inputs = input
model =  keras.Model(inputs, x, name='VGG16')
model.summary()


# plot model architecture
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='VGG16.png')
# Out:
# Model: "VGG16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 64)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 2)                 8194
#
# =================================================================
# Total params: 134,268,738
# Trainable params: 134,268,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("AlexNet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.05, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 86/86 [==============================] - ETA: 0s - loss: 184.3590 - accuracy: 0.6126
# Epoch 1: val_accuracy improved from -inf to 0.67361, saving model to AlexNet.h5
# 86/86 [==============================] - 62s 541ms/step - loss: 184.3590 - accuracy: 0.6126 - val_loss: 0.6306 - val_accuracy: 0.6736 - lr: 0.0010
# Epoch 2/50
# 86/86 [==============================] - ETA: 0s - loss: 0.6475 - accuracy: 0.6594
# Epoch 2: val_accuracy improved from 0.67361 to 0.84028, saving model to AlexNet.h5
# 86/86 [==============================] - 42s 494ms/step - loss: 0.6475 - accuracy: 0.6594 - val_loss: 0.4258 - val_accuracy: 0.8403 - lr: 0.0010
# Epoch 3/50
# 86/86 [==============================] - ETA: 0s - loss: 0.3346 - accuracy: 0.8911
# Epoch 3: val_accuracy improved from 0.84028 to 0.88194, saving model to AlexNet.h5
# 86/86 [==============================] - 43s 501ms/step - loss: 0.3346 - accuracy: 0.8911 - val_loss: 0.3831 - val_accuracy: 0.8819 - lr: 0.0010
# Epoch 4/50
# 86/86 [==============================] - ETA: 0s - loss: 0.2831 - accuracy: 0.9119
# Epoch 4: val_accuracy improved from 0.88194 to 0.92361, saving model to AlexNet.h5
# 86/86 [==============================] - 44s 507ms/step - loss: 0.2831 - accuracy: 0.9119 - val_loss: 0.2800 - val_accuracy: 0.9236 - lr: 0.0010
# Epoch 5/50
# 86/86 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9309
# Epoch 5: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 37s 431ms/step - loss: 0.2258 - accuracy: 0.9309 - val_loss: 0.3098 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 6/50
# 86/86 [==============================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9320
# Epoch 6: val_accuracy did not improve from 0.92361
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 86/86 [==============================] - 37s 428ms/step - loss: 0.2188 - accuracy: 0.9320 - val_loss: 0.3226 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 7/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1938 - accuracy: 0.9393
# Epoch 7: val_accuracy improved from 0.92361 to 0.94444, saving model to AlexNet.h5
# 86/86 [==============================] - 44s 518ms/step - loss: 0.1938 - accuracy: 0.9393 - val_loss: 0.1994 - val_accuracy: 0.9444 - lr: 4.0000e-04
# Epoch 8/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9591
# Epoch 8: val_accuracy improved from 0.94444 to 0.96528, saving model to AlexNet.h5
# 86/86 [==============================] - 44s 511ms/step - loss: 0.1275 - accuracy: 0.9591 - val_loss: 0.1459 - val_accuracy: 0.9653 - lr: 4.0000e-04
# Epoch 9/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9642
# Epoch 9: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 435ms/step - loss: 0.1084 - accuracy: 0.9642 - val_loss: 0.1466 - val_accuracy: 0.9653 - lr: 4.0000e-04
# Epoch 10/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9678
# Epoch 10: val_accuracy did not improve from 0.96528
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 86/86 [==============================] - 38s 437ms/step - loss: 0.0968 - accuracy: 0.9678 - val_loss: 0.1376 - val_accuracy: 0.9583 - lr: 4.0000e-04
# Epoch 11/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0840 - accuracy: 0.9762
# Epoch 11: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 38s 439ms/step - loss: 0.0840 - accuracy: 0.9762 - val_loss: 0.1207 - val_accuracy: 0.9583 - lr: 1.6000e-04
# Epoch 12/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9773
# Epoch 12: val_accuracy did not improve from 0.96528
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 86/86 [==============================] - 38s 440ms/step - loss: 0.0688 - accuracy: 0.9773 - val_loss: 0.0975 - val_accuracy: 0.9583 - lr: 1.6000e-04
# Epoch 13/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9788
# Epoch 13: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 433ms/step - loss: 0.0579 - accuracy: 0.9788 - val_loss: 0.1032 - val_accuracy: 0.9514 - lr: 6.4000e-05
# Epoch 14/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9810
# Epoch 14: val_accuracy did not improve from 0.96528
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 86/86 [==============================] - 38s 440ms/step - loss: 0.0520 - accuracy: 0.9810 - val_loss: 0.1013 - val_accuracy: 0.9583 - lr: 6.4000e-05
# Epoch 15/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9828
# Epoch 15: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 433ms/step - loss: 0.0472 - accuracy: 0.9828 - val_loss: 0.0937 - val_accuracy: 0.9514 - lr: 2.5600e-05
# Epoch 16/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9854
# Epoch 16: val_accuracy did not improve from 0.96528
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 86/86 [==============================] - 37s 433ms/step - loss: 0.0436 - accuracy: 0.9854 - val_loss: 0.0944 - val_accuracy: 0.9514 - lr: 2.5600e-05
# Epoch 17/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9865
# Epoch 17: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 433ms/step - loss: 0.0409 - accuracy: 0.9865 - val_loss: 0.0910 - val_accuracy: 0.9514 - lr: 1.0240e-05
# Epoch 18/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9865
# Epoch 18: val_accuracy did not improve from 0.96528
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 86/86 [==============================] - 38s 440ms/step - loss: 0.0397 - accuracy: 0.9865 - val_loss: 0.0893 - val_accuracy: 0.9514 - lr: 1.0240e-05
# Epoch 19/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9861
# Epoch 19: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 38s 440ms/step - loss: 0.0385 - accuracy: 0.9861 - val_loss: 0.0894 - val_accuracy: 0.9514 - lr: 4.0960e-06
# Epoch 20/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9868
# Epoch 20: val_accuracy did not improve from 0.96528
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 86/86 [==============================] - 37s 434ms/step - loss: 0.0380 - accuracy: 0.9868 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 4.0960e-06
# Epoch 21/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0375 - accuracy: 0.9868
# Epoch 21: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 434ms/step - loss: 0.0375 - accuracy: 0.9868 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.6384e-06
# Epoch 22/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9868
# Epoch 22: val_accuracy did not improve from 0.96528
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 86/86 [==============================] - 37s 433ms/step - loss: 0.0373 - accuracy: 0.9868 - val_loss: 0.0884 - val_accuracy: 0.9514 - lr: 1.6384e-06
# Epoch 23/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9872
# Epoch 23: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 38s 440ms/step - loss: 0.0371 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 6.5536e-07
# Epoch 24/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9872
# Epoch 24: val_accuracy did not improve from 0.96528
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 86/86 [==============================] - 37s 434ms/step - loss: 0.0370 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 6.5536e-07
# Epoch 25/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9872
# Epoch 25: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 38s 438ms/step - loss: 0.0370 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 2.6214e-07
# Epoch 26/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 26: val_accuracy did not improve from 0.96528
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 86/86 [==============================] - 37s 434ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 2.6214e-07
# Epoch 27/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 27: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 435ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.0486e-07
# Epoch 28/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 28: val_accuracy did not improve from 0.96528
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 86/86 [==============================] - 38s 444ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.0486e-07
# Epoch 29/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 29: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 38s 437ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 4.1943e-08
# Epoch 30/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 30: val_accuracy did not improve from 0.96528
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 86/86 [==============================] - 38s 442ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 4.1943e-08
# Epoch 31/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 31: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 38s 444ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.6777e-08
# Epoch 32/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 32: val_accuracy did not improve from 0.96528
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.710887134886434e-09.
# 86/86 [==============================] - 37s 435ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.6777e-08
# Epoch 33/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 33: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 38s 441ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 6.7109e-09
# Epoch 34/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 34: val_accuracy did not improve from 0.96528
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.6843547829003003e-09.
# 86/86 [==============================] - 38s 442ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 6.7109e-09
# Epoch 35/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 35: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 435ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 2.6844e-09
# Epoch 36/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 36: val_accuracy did not improve from 0.96528
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0737418953965518e-09.
# 86/86 [==============================] - 38s 442ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 2.6844e-09
# Epoch 37/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 37: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 434ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.0737e-09
# Epoch 38/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 38: val_accuracy did not improve from 0.96528
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.294967492768365e-10.
# 86/86 [==============================] - 38s 441ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.0737e-09
# Epoch 39/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 39: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 434ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 4.2950e-10
# Epoch 40/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 40: val_accuracy did not improve from 0.96528
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.7179869749028854e-10.
# 86/86 [==============================] - 37s 433ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 4.2950e-10
# Epoch 41/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 41: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 38s 440ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.7180e-10
# Epoch 42/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 42: val_accuracy did not improve from 0.96528
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.871948010633844e-11.
# 86/86 [==============================] - 37s 433ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.7180e-10
# Epoch 43/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 43: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 38s 441ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 6.8719e-11
# Epoch 44/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 44: val_accuracy did not improve from 0.96528
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.748779259764689e-11.
# 86/86 [==============================] - 37s 434ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 6.8719e-11
# Epoch 45/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 45: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 434ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 2.7488e-11
# Epoch 46/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 46: val_accuracy did not improve from 0.96528
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.0995117316614512e-11.
# 86/86 [==============================] - 38s 441ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 2.7488e-11
# Epoch 47/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 47: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 37s 434ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.0995e-11
# Epoch 48/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 48: val_accuracy did not improve from 0.96528
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 4.398046857256866e-12.
# 86/86 [==============================] - 37s 434ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 1.0995e-11
# Epoch 49/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 49: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 38s 440ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 4.3980e-12
# Epoch 50/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 50: val_accuracy did not improve from 0.96528
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.7592188122916854e-12.
# 86/86 [==============================] - 38s 442ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0883 - val_accuracy: 0.9514 - lr: 4.3980e-12

# %%
#plot the loss curve
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.ylabel('Loss',fontweight='bold')
plt.title('Loss Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('Covid_VGG16_LossCurve',dpi=400)
plt.legend()

# %%
#plot the accuracy curve
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.ylabel('Accuracy',fontweight='bold')
plt.title('Accuracy Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('Covid_VGG16_AccCurve',dpi=400)
plt.legend()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 10/10 [==============================] - 2s 151ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       210
#            1       0.98      0.98      0.98       110
#
#     accuracy                           0.99       320
#    macro avg       0.99      0.99      0.99       320
# weighted avg       0.99      0.99      0.99       320

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm,labels)
plt.savefig('VGG16NetCM',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.5f' % accuracy_score(y_test_new, pred), 'Precision: %.5f' % precision_score(y_test_new, pred),' Recall: %.5f' % recall_score(y_test_new, pred), 
      'F1 Score: %.5f' % f1_score(y_test_new, pred), 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.98750 Precision: 0.98182  Recall: 0.98182 F1 Score: 0.98182 AUC Score: 0.98615

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
print('TP = %.5f'%TP, 'TN = %.5f'%TN, 'FP = %.5f'%FP, 'FN = %.5f'%FN)
# Out:
# TP = 108.00000 TN = 208.00000 FP = 2.00000 FN = 2.00000

# %%
specificity=TN/float(TN+FP)
print('Specificity: %.5f' % specificity)
# Out:
# Specificity: 0.99048

# %%
recall=TP/float(TP+FN)
print(' Recall: %.5f' % recall)
precision=TP/float(TP+FP)
print(' Precision: %.5f' % precision)
# Out:
#  Recall: 0.98182
#  Precision: 0.98182

# %%
f1=(2*precision*recall)/(recall+precision)
print('F1 Score: %.5f' % f1)
# Out:
# F1 Score: 0.98182

# %%
print( 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# AUC Score: 0.98615

# %%
from sklearn.metrics import mean_squared_error
print( 'Error Rate: %.5f' % mean_squared_error(y_test_new, pred))
# Out:
# Error Rate: 0.01250

# %%
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.ylabel('Recall')
plt.xlabel('Fall-out (1-Specificity)')
plt.savefig('Covid_VGG16AUC',dpi=400)
plt.show()

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
print('val_accuracy: {0:0.2f}%'.format(np.round((history.history['val_accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 98.75%
# Precision: 98.18%
# Recall or Sensitivity: 98.18%
# Specificity: 99.05%
# F1-score: 98.18%
# AUC-score: 98.61%
# Train acc: 98.72%
# val_accuracy: 95.14%

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score
from scipy import interp
from itertools import cycle

# %%
# Plot linewidth.
lw = 1

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test_new, pred)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_new.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(2)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(2):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= 2

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
plt.title('Receiver Operating Characteristic (ROC) Curve')
# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'cornflowerblue'])
for i, color in zip(range(2), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.savefig('Covid_VGG16_ROC',dpi=400)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
