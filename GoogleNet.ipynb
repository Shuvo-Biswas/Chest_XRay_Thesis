# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Covid)','Normal']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/chest_xray_dataset3200/chest_xray_dataset3200/train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 2070/2070 [00:42<00:00, 48.18it/s]
# 100%|██████████| 1130/1130 [00:19<00:00, 56.96it/s]

# %%
X_train.shape
# Out:
# (3200, 224, 224, 3)

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model

from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow

# %% [markdown]
# Model Build

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, \
     Concatenate, AvgPool2D, Dropout, Flatten, Dense
      
def inception_block(x, filters):
    t1 = Conv2D(filters=filters[0], kernel_size=1, activation='relu')(x)

    t2 = Conv2D(filters=filters[1], kernel_size=1, activation='relu')(x)
    t2 = Conv2D(filters=filters[2], kernel_size=3, padding='same', activation='relu')(t2)

    t3 = Conv2D(filters=filters[3], kernel_size=1, activation='relu')(x)
    t3 = Conv2D(filters=filters[4], kernel_size=5, padding='same', activation='relu')(t3)

    t4 = MaxPool2D(pool_size=3, strides=1, padding='same')(x)
    t4 = Conv2D(filters=filters[5], kernel_size=1, activation='relu')(t4)

    output = Concatenate()([t1, t2, t3, t4])
    return output


input = Input(shape=(224, 224, 3))
x = Conv2D(filters=64, kernel_size=7, strides=2, padding='same', activation='relu')(input)
x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

x = Conv2D(filters=64, kernel_size=1, activation='relu')(x)
x = Conv2D(filters=192, kernel_size=3, padding='same', activation='relu')(x)
x = MaxPool2D(pool_size=3, strides=2)(x)

x = inception_block(x, filters=[64, 96, 128, 16, 32, 32])
x = inception_block(x, filters=[128, 128, 192, 32, 96, 64])
x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

x = inception_block(x, filters=[192, 96, 208, 16, 48, 64])
x = inception_block(x, filters=[160, 112, 224, 24, 64, 64])
x = inception_block(x, filters=[128, 128, 256, 24, 64, 64])
x = inception_block(x, filters=[112, 144, 288, 32, 64, 64])
x = inception_block(x, filters=[256, 160, 320, 32, 128, 128])
x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

x = inception_block(x, filters=[256, 160, 320, 32, 128, 128])
x = inception_block(x, filters=[384, 192, 384, 48, 128, 128])
x = AvgPool2D(pool_size=7, strides=1)(x)
x = Dropout(rate=0.4)(x)

x = Flatten()(x)
output = Dense(units=2, activation='softmax')(x)
from tensorflow.keras import Model 
model = Model(input, output,  name='DenseNet121')

# %%
model.summary()
# Out:
# Model: "DenseNet121"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_57 (Conv2D)             (None, 112, 112, 64  9472        ['input_2[0][0]']
#                                 )
#
#  max_pooling2d_13 (MaxPooling2D  (None, 56, 56, 64)  0           ['conv2d_57[0][0]']
#  )
#
#  conv2d_58 (Conv2D)             (None, 56, 56, 64)   4160        ['max_pooling2d_13[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 56, 56, 192)  110784      ['conv2d_58[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 27, 27, 192)  0          ['conv2d_59[0][0]']
#  )
#
#  conv2d_61 (Conv2D)             (None, 27, 27, 96)   18528       ['max_pooling2d_14[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 27, 27, 16)   3088        ['max_pooling2d_14[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 27, 27, 192)  0          ['max_pooling2d_14[0][0]']
#  )
#
#  conv2d_60 (Conv2D)             (None, 27, 27, 64)   12352       ['max_pooling2d_14[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 27, 27, 128)  110720      ['conv2d_61[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 27, 27, 32)   12832       ['conv2d_63[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 27, 27, 32)   6176        ['max_pooling2d_15[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 27, 27, 256)  0           ['conv2d_60[0][0]',
#                                                                   'conv2d_62[0][0]',
#                                                                   'conv2d_64[0][0]',
#                                                                   'conv2d_65[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 27, 27, 128)  32896       ['concatenate_9[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 27, 27, 32)   8224        ['concatenate_9[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 27, 27, 256)  0          ['concatenate_9[0][0]']
#  )
#
#  conv2d_66 (Conv2D)             (None, 27, 27, 128)  32896       ['concatenate_9[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 27, 27, 192)  221376      ['conv2d_67[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 27, 27, 96)   76896       ['conv2d_69[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 27, 27, 64)   16448       ['max_pooling2d_16[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 27, 27, 480)  0           ['conv2d_66[0][0]',
#                                                                   'conv2d_68[0][0]',
#                                                                   'conv2d_70[0][0]',
#                                                                   'conv2d_71[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 14, 14, 480)  0          ['concatenate_10[0][0]']
#  )
#
#  conv2d_73 (Conv2D)             (None, 14, 14, 96)   46176       ['max_pooling2d_17[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 14, 14, 16)   7696        ['max_pooling2d_17[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 14, 14, 480)  0          ['max_pooling2d_17[0][0]']
#  )
#
#  conv2d_72 (Conv2D)             (None, 14, 14, 192)  92352       ['max_pooling2d_17[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 14, 14, 208)  179920      ['conv2d_73[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 14, 14, 48)   19248       ['conv2d_75[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 14, 14, 64)   30784       ['max_pooling2d_18[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 14, 14, 512)  0           ['conv2d_72[0][0]',
#                                                                   'conv2d_74[0][0]',
#                                                                   'conv2d_76[0][0]',
#                                                                   'conv2d_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_11[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_11[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_11[0][0]']
#  )
#
#  conv2d_78 (Conv2D)             (None, 14, 14, 160)  82080       ['concatenate_11[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 14, 14, 224)  226016      ['conv2d_79[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_19[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 14, 14, 512)  0           ['conv2d_78[0][0]',
#                                                                   'conv2d_80[0][0]',
#                                                                   'conv2d_82[0][0]',
#                                                                   'conv2d_83[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_12[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_12[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_12[0][0]']
#  )
#
#  conv2d_84 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_12[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 14, 14, 256)  295168      ['conv2d_85[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_87[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_20[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 14, 14, 512)  0           ['conv2d_84[0][0]',
#                                                                   'conv2d_86[0][0]',
#                                                                   'conv2d_88[0][0]',
#                                                                   'conv2d_89[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 14, 14, 144)  73872       ['concatenate_13[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 14, 14, 32)   16416       ['concatenate_13[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_13[0][0]']
#  )
#
#  conv2d_90 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_13[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 14, 14, 288)  373536      ['conv2d_91[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 14, 14, 64)   51264       ['conv2d_93[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_21[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 14, 14, 528)  0           ['conv2d_90[0][0]',
#                                                                   'conv2d_92[0][0]',
#                                                                   'conv2d_94[0][0]',
#                                                                   'conv2d_95[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 14, 14, 160)  84640       ['concatenate_14[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 14, 14, 32)   16928       ['concatenate_14[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 14, 14, 528)  0          ['concatenate_14[0][0]']
#  )
#
#  conv2d_96 (Conv2D)             (None, 14, 14, 256)  135424      ['concatenate_14[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 14, 14, 320)  461120      ['conv2d_97[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 14, 14, 128)  102528      ['conv2d_99[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 14, 14, 128)  67712       ['max_pooling2d_22[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 14, 14, 832)  0           ['conv2d_96[0][0]',
#                                                                   'conv2d_98[0][0]',
#                                                                   'conv2d_100[0][0]',
#                                                                   'conv2d_101[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_15[0][0]']
#  )
#
#  conv2d_103 (Conv2D)            (None, 7, 7, 160)    133280      ['max_pooling2d_23[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 7, 7, 32)     26656       ['max_pooling2d_23[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D  (None, 7, 7, 832)   0           ['max_pooling2d_23[0][0]']
#  )
#
#  conv2d_102 (Conv2D)            (None, 7, 7, 256)    213248      ['max_pooling2d_23[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 7, 7, 320)    461120      ['conv2d_103[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 7, 7, 128)    102528      ['conv2d_105[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 7, 7, 128)    106624      ['max_pooling2d_24[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 7, 7, 832)    0           ['conv2d_102[0][0]',
#                                                                   'conv2d_104[0][0]',
#                                                                   'conv2d_106[0][0]',
#                                                                   'conv2d_107[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 7, 7, 192)    159936      ['concatenate_16[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 7, 7, 48)     39984       ['concatenate_16[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_16[0][0]']
#  )
#
#  conv2d_108 (Conv2D)            (None, 7, 7, 384)    319872      ['concatenate_16[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 7, 7, 384)    663936      ['conv2d_109[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 7, 7, 128)    153728      ['conv2d_111[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 7, 7, 128)    106624      ['max_pooling2d_25[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 7, 7, 1024)   0           ['conv2d_108[0][0]',
#                                                                   'conv2d_110[0][0]',
#                                                                   'conv2d_112[0][0]',
#                                                                   'conv2d_113[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 1, 1, 1024)  0           ['concatenate_17[0][0]']
#  oling2D)
#
#  dropout_1 (Dropout)            (None, 1, 1, 1024)   0           ['average_pooling2d_1[0][0]']
#
#  flatten_1 (Flatten)            (None, 1024)         0           ['dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 2)            2050        ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 5,975,602
# Trainable params: 5,975,602
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("GoogleNet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.05, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 86/86 [==============================] - ETA: 0s - loss: 1.0741 - accuracy: 0.6382
# Epoch 1: val_accuracy improved from -inf to 0.92361, saving model to GoogleNet.h5
# 86/86 [==============================] - 33s 161ms/step - loss: 1.0741 - accuracy: 0.6382 - val_loss: 0.2695 - val_accuracy: 0.9236 - lr: 0.0010
# Epoch 2/50
# 86/86 [==============================] - ETA: 0s - loss: 0.2546 - accuracy: 0.9189
# Epoch 2: val_accuracy improved from 0.92361 to 0.96528, saving model to GoogleNet.h5
# 86/86 [==============================] - 10s 116ms/step - loss: 0.2546 - accuracy: 0.9189 - val_loss: 0.1205 - val_accuracy: 0.9653 - lr: 0.0010
# Epoch 3/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1734 - accuracy: 0.9499
# Epoch 3: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 9s 110ms/step - loss: 0.1734 - accuracy: 0.9499 - val_loss: 0.1102 - val_accuracy: 0.9653 - lr: 0.0010
# Epoch 4/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1489 - accuracy: 0.9613
# Epoch 4: val_accuracy did not improve from 0.96528
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 86/86 [==============================] - 10s 114ms/step - loss: 0.1489 - accuracy: 0.9613 - val_loss: 0.1342 - val_accuracy: 0.9653 - lr: 0.0010
# Epoch 5/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1277 - accuracy: 0.9667
# Epoch 5: val_accuracy improved from 0.96528 to 0.97222, saving model to GoogleNet.h5
# 86/86 [==============================] - 10s 121ms/step - loss: 0.1277 - accuracy: 0.9667 - val_loss: 0.1009 - val_accuracy: 0.9722 - lr: 4.0000e-04
# Epoch 6/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9715
# Epoch 6: val_accuracy improved from 0.97222 to 0.97917, saving model to GoogleNet.h5
# 86/86 [==============================] - 10s 115ms/step - loss: 0.1048 - accuracy: 0.9715 - val_loss: 0.1085 - val_accuracy: 0.9792 - lr: 4.0000e-04
# Epoch 7/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1004 - accuracy: 0.9711
# Epoch 7: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 109ms/step - loss: 0.1004 - accuracy: 0.9711 - val_loss: 0.1013 - val_accuracy: 0.9792 - lr: 4.0000e-04
# Epoch 8/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9708
# Epoch 8: val_accuracy did not improve from 0.97917
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 86/86 [==============================] - 9s 109ms/step - loss: 0.0970 - accuracy: 0.9708 - val_loss: 0.1025 - val_accuracy: 0.9792 - lr: 4.0000e-04
# Epoch 9/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9788
# Epoch 9: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0767 - accuracy: 0.9788 - val_loss: 0.0943 - val_accuracy: 0.9792 - lr: 1.6000e-04
# Epoch 10/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9806
# Epoch 10: val_accuracy did not improve from 0.97917
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0620 - accuracy: 0.9806 - val_loss: 0.0965 - val_accuracy: 0.9792 - lr: 1.6000e-04
# Epoch 11/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9828
# Epoch 11: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 10s 112ms/step - loss: 0.0501 - accuracy: 0.9828 - val_loss: 0.0964 - val_accuracy: 0.9722 - lr: 6.4000e-05
# Epoch 12/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9857
# Epoch 12: val_accuracy did not improve from 0.97917
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0420 - accuracy: 0.9857 - val_loss: 0.0943 - val_accuracy: 0.9792 - lr: 6.4000e-05
# Epoch 13/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9894
# Epoch 13: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0349 - accuracy: 0.9894 - val_loss: 0.0890 - val_accuracy: 0.9792 - lr: 2.5600e-05
# Epoch 14/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9876
# Epoch 14: val_accuracy did not improve from 0.97917
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 86/86 [==============================] - 10s 112ms/step - loss: 0.0326 - accuracy: 0.9876 - val_loss: 0.0901 - val_accuracy: 0.9792 - lr: 2.5600e-05
# Epoch 15/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9905
# Epoch 15: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0295 - accuracy: 0.9905 - val_loss: 0.0905 - val_accuracy: 0.9792 - lr: 1.0240e-05
# Epoch 16/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9909
# Epoch 16: val_accuracy did not improve from 0.97917
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 86/86 [==============================] - 10s 112ms/step - loss: 0.0263 - accuracy: 0.9909 - val_loss: 0.0885 - val_accuracy: 0.9792 - lr: 1.0240e-05
# Epoch 17/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9905
# Epoch 17: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 10s 113ms/step - loss: 0.0264 - accuracy: 0.9905 - val_loss: 0.0894 - val_accuracy: 0.9792 - lr: 4.0960e-06
# Epoch 18/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9912
# Epoch 18: val_accuracy did not improve from 0.97917
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0257 - accuracy: 0.9912 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 4.0960e-06
# Epoch 19/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9927
# Epoch 19: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 10s 112ms/step - loss: 0.0239 - accuracy: 0.9927 - val_loss: 0.0897 - val_accuracy: 0.9792 - lr: 1.6384e-06
# Epoch 20/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9923
# Epoch 20: val_accuracy did not improve from 0.97917
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0237 - accuracy: 0.9923 - val_loss: 0.0899 - val_accuracy: 0.9792 - lr: 1.6384e-06
# Epoch 21/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9927
# Epoch 21: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0232 - accuracy: 0.9927 - val_loss: 0.0899 - val_accuracy: 0.9792 - lr: 6.5536e-07
# Epoch 22/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9931
# Epoch 22: val_accuracy did not improve from 0.97917
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 86/86 [==============================] - 10s 112ms/step - loss: 0.0237 - accuracy: 0.9931 - val_loss: 0.0899 - val_accuracy: 0.9792 - lr: 6.5536e-07
# Epoch 23/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9912
# Epoch 23: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0239 - accuracy: 0.9912 - val_loss: 0.0899 - val_accuracy: 0.9792 - lr: 2.6214e-07
# Epoch 24/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9927
# Epoch 24: val_accuracy did not improve from 0.97917
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0229 - accuracy: 0.9927 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 2.6214e-07
# Epoch 25/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9931
# Epoch 25: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 109ms/step - loss: 0.0228 - accuracy: 0.9931 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.0486e-07
# Epoch 26/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9931
# Epoch 26: val_accuracy did not improve from 0.97917
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0236 - accuracy: 0.9931 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.0486e-07
# Epoch 27/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9923
# Epoch 27: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0234 - accuracy: 0.9923 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 4.1943e-08
# Epoch 28/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9927
# Epoch 28: val_accuracy did not improve from 0.97917
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 86/86 [==============================] - 10s 112ms/step - loss: 0.0237 - accuracy: 0.9927 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 4.1943e-08
# Epoch 29/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9931
# Epoch 29: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0229 - accuracy: 0.9931 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.6777e-08
# Epoch 30/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9916
# Epoch 30: val_accuracy did not improve from 0.97917
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.710887134886434e-09.
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0243 - accuracy: 0.9916 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.6777e-08
# Epoch 31/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9912
# Epoch 31: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 109ms/step - loss: 0.0241 - accuracy: 0.9912 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 6.7109e-09
# Epoch 32/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9923
# Epoch 32: val_accuracy did not improve from 0.97917
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.6843547829003003e-09.
# 86/86 [==============================] - 9s 109ms/step - loss: 0.0237 - accuracy: 0.9923 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 6.7109e-09
# Epoch 33/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9920
# Epoch 33: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 10s 112ms/step - loss: 0.0228 - accuracy: 0.9920 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 2.6844e-09
# Epoch 34/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9920
# Epoch 34: val_accuracy did not improve from 0.97917
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0737418953965518e-09.
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0240 - accuracy: 0.9920 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 2.6844e-09
# Epoch 35/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9931
# Epoch 35: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0236 - accuracy: 0.9931 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.0737e-09
# Epoch 36/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9934
# Epoch 36: val_accuracy did not improve from 0.97917
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 4.294967492768365e-10.
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0227 - accuracy: 0.9934 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.0737e-09
# Epoch 37/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9923
# Epoch 37: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 109ms/step - loss: 0.0242 - accuracy: 0.9923 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 4.2950e-10
# Epoch 38/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9927
# Epoch 38: val_accuracy did not improve from 0.97917
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.7179869749028854e-10.
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0243 - accuracy: 0.9927 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 4.2950e-10
# Epoch 39/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9927
# Epoch 39: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0239 - accuracy: 0.9927 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.7180e-10
# Epoch 40/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9927
# Epoch 40: val_accuracy did not improve from 0.97917
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 6.871948010633844e-11.
# 86/86 [==============================] - 9s 109ms/step - loss: 0.0219 - accuracy: 0.9927 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.7180e-10
# Epoch 41/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9923
# Epoch 41: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 109ms/step - loss: 0.0233 - accuracy: 0.9923 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 6.8719e-11
# Epoch 42/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9923
# Epoch 42: val_accuracy did not improve from 0.97917
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 2.748779259764689e-11.
# 86/86 [==============================] - 9s 109ms/step - loss: 0.0238 - accuracy: 0.9923 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 6.8719e-11
# Epoch 43/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9916
# Epoch 43: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0238 - accuracy: 0.9916 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 2.7488e-11
# Epoch 44/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9938
# Epoch 44: val_accuracy did not improve from 0.97917
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0995117316614512e-11.
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0228 - accuracy: 0.9938 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 2.7488e-11
# Epoch 45/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9927
# Epoch 45: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 110ms/step - loss: 0.0231 - accuracy: 0.9927 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.0995e-11
# Epoch 46/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9916
# Epoch 46: val_accuracy did not improve from 0.97917
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 4.398046857256866e-12.
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0249 - accuracy: 0.9916 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.0995e-11
# Epoch 47/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9920
# Epoch 47: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0240 - accuracy: 0.9920 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 4.3980e-12
# Epoch 48/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9920
# Epoch 48: val_accuracy did not improve from 0.97917
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.7592188122916854e-12.
# 86/86 [==============================] - 9s 109ms/step - loss: 0.0236 - accuracy: 0.9920 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 4.3980e-12
# Epoch 49/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9923
# Epoch 49: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 9s 109ms/step - loss: 0.0236 - accuracy: 0.9923 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.7592e-12
# Epoch 50/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9923
# Epoch 50: val_accuracy did not improve from 0.97917
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 7.036875422639088e-13.
# 86/86 [==============================] - 10s 111ms/step - loss: 0.0236 - accuracy: 0.9923 - val_loss: 0.0900 - val_accuracy: 0.9792 - lr: 1.7592e-12

# %%
#plot the loss curve
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.ylabel('Loss',fontweight='bold')
plt.title('Loss Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('GoogleNet_LossCurve',dpi=400)
plt.legend()

# %%
#plot the accuracy curve
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.ylabel('Accuracy',fontweight='bold')
plt.title('Accuracy Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('GoogleNet_AccCurve',dpi=400)
plt.legend()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 10/10 [==============================] - 1s 42ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       210
#            1       0.96      0.97      0.96       110
#
#     accuracy                           0.97       320
#    macro avg       0.97      0.97      0.97       320
# weighted avg       0.98      0.97      0.98       320

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm,labels)
plt.savefig('GoogleNetCM',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.5f' % accuracy_score(y_test_new, pred), 'Precision: %.5f' % precision_score(y_test_new, pred),' Recall: %.5f' % recall_score(y_test_new, pred), 
      'F1 Score: %.5f' % f1_score(y_test_new, pred), 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.97500 Precision: 0.95536  Recall: 0.97273 F1 Score: 0.96396 AUC Score: 0.97446

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
print('TP = %.5f'%TP, 'TN = %.5f'%TN, 'FP = %.5f'%FP, 'FN = %.5f'%FN)
# Out:
# TP = 107.00000 TN = 205.00000 FP = 5.00000 FN = 3.00000

# %%
specificity=TN/float(TN+FP)
print('Specificity: %.5f' % specificity)
# Out:
# Specificity: 0.97619

# %%
recall=TP/float(TP+FN)
print(' Recall: %.5f' % recall)
precision=TP/float(TP+FP)
print(' Precision: %.5f' % precision)
# Out:
#  Recall: 0.97273
#  Precision: 0.95536

# %%
f1=(2*precision*recall)/(recall+precision)
print('F1 Score: %.5f' % f1)
# Out:
# F1 Score: 0.96396

# %%
print( 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# AUC Score: 0.97446

# %%
from sklearn.metrics import mean_squared_error
print( 'Error Rate: %.5f' % mean_squared_error(y_test_new, pred))
# Out:
# Error Rate: 0.02500

# %%
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.ylabel('Recall')
plt.xlabel('Fall-out (1-Specificity)')
plt.savefig('GoogleNetAUC',dpi=400)
plt.show()

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
print('val_accuracy: {0:0.2f}%'.format(np.round((history.history['val_accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 97.50%
# Precision: 95.54%
# Recall or Sensitivity: 97.27%
# Specificity: 97.62%
# F1-score: 96.40%
# AUC-score: 97.45%
# Train acc: 99.23%
# val_accuracy: 97.92%

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score
from scipy import interp
from itertools import cycle

# %%
# Plot linewidth.
lw = 1

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test_new, pred)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_new.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(2)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(2):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= 2

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
plt.title('Receiver Operating Characteristic (ROC) Curve')
# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'cornflowerblue'])
for i, color in zip(range(2), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.savefig('GoogleNet_ROC',dpi=400)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
