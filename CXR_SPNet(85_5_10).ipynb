# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Covid)','Normal']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/chest_xray_dataset3200/chest_xray_dataset3200/train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 2070/2070 [00:35<00:00, 57.89it/s]
# 100%|██████████| 1130/1130 [00:18<00:00, 60.54it/s]

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
X_train.shape
# Out:
# (2880, 224, 224, 3)

# %%
X_test.shape
# Out:
# (320, 224, 224, 3)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
#inception naive version

def inception_module(x, f1, f2, f3, f4):
	# 1x1 conv
	conv1 =  keras.layers.Conv2D(f1, (1,1), padding='same', activation='relu')(x)
	# 3x3 conv
	conv3 = keras.layers.Conv2D(f2, (3,3), padding='same', activation='relu')(x)
	# 5x5 conv
	conv5 = keras.layers.Conv2D(f3, (5,5), padding='same', activation='relu')(x)
  # 7x7 conv
	conv6 = keras.layers.Conv2D(f4, (7,7), padding='same', activation='relu')(x)
	# 3x3 max pooling
	pool = keras.layers.MaxPooling2D((3,3), strides=(1,1), padding='same')(x)
	# concatenate filters
	out = keras.layers.merge.concatenate([conv1, conv3, conv5, conv6, pool])
	return out

# %%
img_input = keras.Input(shape=(224, 224, 3))
classes=2
channel_axis=3

# %%
def conv2d_bn(x,filters,num_row,num_col,padding='same',strides=(1, 1)):
   
    x = keras.layers.Conv2D(filters, (num_row, num_col),strides=strides,padding=padding)(x)
    x = keras.layers.BatchNormalization(axis=3, scale=False)(x)
    x = keras.layers.Activation('relu')(x)
    return x

# %%
def inc_block_a(x):    
    branch1x1 = conv2d_bn(x, 64, 1, 1)  # 64 filters of 1*1

    branch5x5 = conv2d_bn(x, 48, 1, 1)  #48 filters of 1*1
    branch5x5 = conv2d_bn(branch5x5, 64, 5, 5)

    branch3x3dbl = conv2d_bn(x, 64, 1, 1)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3)

    branch_pool = keras.layers.AveragePooling2D((3, 3), strides=(1, 1), padding='same')(x)
    branch_pool = conv2d_bn(branch_pool, 32, 1, 1)
    x = keras.layers.concatenate([branch1x1, branch5x5, branch3x3dbl, branch_pool], axis=channel_axis)
    return x

# %%
def reduction_block_a(x):  
    branch3x3 = conv2d_bn(x, 384, 3, 3, strides=(2, 2), padding='valid')

    branch3x3dbl = conv2d_bn(x, 64, 1, 1)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3, strides=(2, 2), padding='valid')

    branch_pool = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)
    x = keras.layers.concatenate([branch3x3, branch3x3dbl, branch_pool],axis=channel_axis)
    return x

# %%
def inc_block_b(x):
    branch1x1 = conv2d_bn(x, 192, 1, 1)

    branch7x7 = conv2d_bn(x, 128, 1, 1)
    branch7x7 = conv2d_bn(branch7x7, 128, 1, 7)
    branch7x7 = conv2d_bn(branch7x7, 192, 7, 1)

    branch7x7dbl = conv2d_bn(x, 128, 1, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 128, 7, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 128, 1, 7)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 128, 7, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 192, 1, 7)

    branch_pool = keras.layers.AveragePooling2D((3, 3), strides=(1, 1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool, 192, 1, 1)
    x = keras.layers.concatenate([branch1x1, branch7x7, branch7x7dbl, branch_pool], axis=channel_axis)
    return x

# %%
def reduction_block_b(x): 
    branch3x3 = conv2d_bn(x, 192, 1, 1)
    branch3x3 = conv2d_bn(branch3x3, 320, 3, 3,strides=(2, 2), padding='valid')

    branch7x7x3 = conv2d_bn(x, 192, 1, 1)
    branch7x7x3 = conv2d_bn(branch7x7x3, 192, 1, 7)
    branch7x7x3 = conv2d_bn(branch7x7x3, 192, 7, 1)
    branch7x7x3 = conv2d_bn( branch7x7x3, 192, 3, 3, strides=(2, 2), padding='valid')

    branch_pool = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)
    x = keras.layers.concatenate([branch3x3, branch7x7x3, branch_pool], axis=channel_axis)
    return x

# %%
def inc_block_c(x):        
        branch1x1 = conv2d_bn(x, 320, 1, 1)

        branch3x3 = conv2d_bn(x, 384, 1, 1)
        branch3x3_1 = conv2d_bn(branch3x3, 384, 1, 3)
        branch3x3_2 = conv2d_bn(branch3x3, 384, 3, 1)
        branch3x3 = keras.layers.concatenate([branch3x3_1, branch3x3_2],axis=channel_axis)

        branch3x3dbl = conv2d_bn(x, 448, 1, 1)
        branch3x3dbl = conv2d_bn(branch3x3dbl, 384, 3, 3)
        branch3x3dbl_1 = conv2d_bn(branch3x3dbl, 384, 1, 3)
        branch3x3dbl_2 = conv2d_bn(branch3x3dbl, 384, 3, 1)
        branch3x3dbl = keras.layers.concatenate([branch3x3dbl_1, branch3x3dbl_2], axis=channel_axis)

        branch_pool = keras.layers.AveragePooling2D((3, 3), strides=(1, 1), padding='same')(x)
        branch_pool = conv2d_bn(branch_pool, 192, 1, 1)
        x = keras.layers.concatenate( [branch1x1, branch3x3, branch3x3dbl, branch_pool],axis=channel_axis)
        return x

# %%
img_input = keras.Input(shape=(224, 224, 3))

# %%
x = conv2d_bn(img_input, 32, 3, 3, strides=(2, 2), padding='valid') # 149 x 149 x 32
x = conv2d_bn(x, 128, 3, 3, padding='valid')  # 147 x 147 x 32
x = conv2d_bn(x, 192, 3, 3) # 147 x 147 x 64

x = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)   # 73  x 73 x 64
x = conv2d_bn(x, 256, 1, 1, padding='valid') # 73 x 73 x 80
x = conv2d_bn(x, 512, 3, 3, padding='valid')  # 71 x 71 x 192
x = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)  # 35 x 35 x 192


x=inc_block_a(x) #35, 35, 256
x=inc_block_a(x) #35, 35, 256
x=inc_block_a(x) #35, 35, 256
x=inc_block_a(x) #35, 35, 256

x=reduction_block_a(x) #17, 17, 736

x=inc_block_b(x) #17, 17, 768
x=inc_block_b(x) #17, 17, 768
x=inc_block_b(x) #17, 17, 768
x=inc_block_b(x) #17, 17, 768
x=inc_block_b(x) #17, 17, 768

x=reduction_block_b(x) #shape=(None, 8, 8, 1280)

x=inc_block_c(x) # shape=(None, 8, 8, 2048) 
x=inc_block_c(x) # shape=(None, 8, 8, 2048) 
x=inc_block_c(x) # shape=(None, 8, 8, 2048) 

x = keras.layers.GlobalAveragePooling2D(name='avg_pool')(x) # shape=(None, 2048)
x = keras.layers.Dropout(0.5)(x)

x = keras.layers.Dense(classes, activation='softmax', name='predictions')(x) #shape=(None, 2) 

# Create model.
inputs = img_input
model =  keras.Model(inputs, x, name='inception_v3')
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 111, 111, 32  896         ['input_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 111, 111, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 111, 111, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 109, 109, 12  36992       ['activation[0][0]']
#                                 8)
#
#  batch_normalization_1 (BatchNo  (None, 109, 109, 12  384        ['conv2d_1[0][0]']
#  rmalization)                   8)
#
#  activation_1 (Activation)      (None, 109, 109, 12  0           ['batch_normalization_1[0][0]']
#                                 8)
#
#  conv2d_2 (Conv2D)              (None, 109, 109, 19  221376      ['activation_1[0][0]']
#                                 2)
#
#  batch_normalization_2 (BatchNo  (None, 109, 109, 19  576        ['conv2d_2[0][0]']
#  rmalization)                   2)
#
#  activation_2 (Activation)      (None, 109, 109, 19  0           ['batch_normalization_2[0][0]']
#                                 2)
#
#  max_pooling2d (MaxPooling2D)   (None, 54, 54, 192)  0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 54, 54, 256)  49408       ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 54, 54, 256)  768        ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 54, 54, 256)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 52, 52, 512)  1180160     ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 52, 52, 512)  1536       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 52, 52, 512)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 25, 25, 512)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 25, 25, 64)   32832       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 25, 25, 48)   24624       ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 25, 25, 96)   55392       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 25, 25, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 25, 25, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 25, 25, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 25, 25, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 25, 25, 512)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 25, 25, 64)   32832       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 25, 25, 64)   76864       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 25, 25, 96)   83040       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 25, 25, 32)   16416       ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 25, 25, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 25, 25, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_11[0][0]']
#
#  concatenate (Concatenate)      (None, 25, 25, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 25, 25, 64)   16448       ['concatenate[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 25, 25, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 25, 25, 48)   12336       ['concatenate[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 25, 25, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 25, 25, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 25, 25, 256)  0          ['concatenate[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 25, 25, 64)   16448       ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 25, 25, 64)   76864       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 25, 25, 96)   83040       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 25, 25, 32)   8224        ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 25, 25, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 25, 25, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 25, 25, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 25, 25, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_18[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 25, 25, 256)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 25, 25, 64)   16448       ['concatenate_1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 25, 25, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 25, 25, 48)   12336       ['concatenate_1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 25, 25, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 25, 25, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 25, 25, 256)  0          ['concatenate_1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 25, 25, 64)   16448       ['concatenate_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 25, 25, 64)   76864       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 25, 25, 96)   83040       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 25, 25, 32)   8224        ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 25, 25, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 25, 25, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 25, 25, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 25, 25, 32)  96          ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_25[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 25, 25, 256)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 25, 25, 64)   16448       ['concatenate_2[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 25, 25, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 25, 25, 48)   12336       ['concatenate_2[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_29[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 25, 25, 48)  144         ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 25, 25, 96)  288         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_27[0][0]']
#
#  activation_30 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_30[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 25, 25, 256)  0          ['concatenate_2[0][0]']
#  oling2D)
#
#  conv2d_26 (Conv2D)             (None, 25, 25, 64)   16448       ['concatenate_2[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 25, 25, 64)   76864       ['activation_27[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 25, 25, 96)   83040       ['activation_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 25, 25, 32)   8224        ['average_pooling2d_3[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 25, 25, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 25, 25, 64)  192         ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 25, 25, 96)  288         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 25, 25, 32)  96          ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_26[0][0]']
#
#  activation_28 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_28[0][0]']
#
#  activation_31 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_31[0][0]']
#
#  activation_32 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_32[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 25, 25, 256)  0           ['activation_26[0][0]',
#                                                                   'activation_28[0][0]',
#                                                                   'activation_31[0][0]',
#                                                                   'activation_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 25, 25, 64)   16448       ['concatenate_3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 25, 25, 64)  192         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 25, 25, 96)   55392       ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 25, 25, 96)  288         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 12, 12, 384)  885120      ['concatenate_3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 12, 12, 96)   83040       ['activation_35[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 12, 12, 384)  1152       ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 12, 12, 96)  288         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 12, 12, 384)  0           ['batch_normalization_33[0][0]']
#
#  activation_36 (Activation)     (None, 12, 12, 96)   0           ['batch_normalization_36[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 256)  0          ['concatenate_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 12, 12, 736)  0           ['activation_33[0][0]',
#                                                                   'activation_36[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 12, 12, 128)  94336       ['concatenate_4[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 12, 12, 128)  384        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 12, 12, 128)  114816      ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 12, 12, 128)  384        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 12, 12, 128)  94336       ['concatenate_4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 12, 12, 128)  114816      ['activation_42[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 12, 12, 128)  384        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 12, 12, 128)  384        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_38[0][0]']
#
#  activation_43 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 12, 12, 128)  114816      ['activation_38[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 12, 12, 128)  114816      ['activation_43[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 12, 12, 128)  384        ['conv2d_39[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 12, 12, 128)  384        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_39[0][0]']
#
#  activation_44 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_44[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 12, 12, 736)  0          ['concatenate_4[0][0]']
#  oling2D)
#
#  conv2d_37 (Conv2D)             (None, 12, 12, 192)  141504      ['concatenate_4[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 12, 12, 192)  172224      ['activation_39[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 12, 12, 192)  172224      ['activation_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 12, 12, 192)  141504      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 12, 12, 192)  576        ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 12, 12, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 12, 12, 192)  576        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 12, 12, 192)  576        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_45 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_45[0][0]']
#
#  activation_46 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_46[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 12, 12, 768)  0           ['activation_37[0][0]',
#                                                                   'activation_40[0][0]',
#                                                                   'activation_45[0][0]',
#                                                                   'activation_46[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 12, 12, 128)  98432       ['concatenate_5[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 12, 12, 128)  384        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 12, 12, 128)  114816      ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 12, 12, 128)  384        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 12, 12, 128)  98432       ['concatenate_5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 12, 12, 128)  114816      ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 12, 12, 128)  384        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 12, 12, 128)  384        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_48[0][0]']
#
#  activation_53 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 12, 12, 128)  114816      ['activation_48[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 12, 12, 128)  114816      ['activation_53[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 12, 12, 128)  384        ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_54 (BatchN  (None, 12, 12, 128)  384        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_49[0][0]']
#
#  activation_54 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_54[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 12, 12, 768)  0          ['concatenate_5[0][0]']
#  oling2D)
#
#  conv2d_47 (Conv2D)             (None, 12, 12, 192)  147648      ['concatenate_5[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 12, 12, 192)  172224      ['activation_49[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 12, 12, 192)  172224      ['activation_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 12, 12, 192)  147648      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 12, 12, 192)  576        ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 12, 12, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 12, 12, 192)  576        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 12, 12, 192)  576        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_47[0][0]']
#
#  activation_50 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_55 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_55[0][0]']
#
#  activation_56 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_56[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 12, 12, 768)  0           ['activation_47[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_55[0][0]',
#                                                                   'activation_56[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 12, 12, 128)  98432       ['concatenate_6[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 12, 12, 128)  384        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 12, 12, 128)  114816      ['activation_61[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 12, 12, 128)  384        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_62[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 12, 12, 128)  98432       ['concatenate_6[0][0]']
# ...
#  Normalization)
#
#  activation_106 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_106[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 5, 5, 384)    786816      ['concatenate_13[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 5, 5, 384)    1548672     ['activation_106[0][0]']
#
#  batch_normalization_103 (Batch  (None, 5, 5, 384)   1152        ['conv2d_103[0][0]']
#  Normalization)
#
#  batch_normalization_107 (Batch  (None, 5, 5, 384)   1152        ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_103[0][0]']
#
#  activation_107 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_107[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 5, 5, 384)    442752      ['activation_103[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 5, 5, 384)    442752      ['activation_103[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 5, 5, 384)    442752      ['activation_107[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 5, 5, 384)    442752      ['activation_107[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 5, 5, 2048)  0           ['concatenate_13[0][0]']
#  ooling2D)
#
#  conv2d_102 (Conv2D)            (None, 5, 5, 320)    655680      ['concatenate_13[0][0]']
#
#  batch_normalization_104 (Batch  (None, 5, 5, 384)   1152        ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 5, 5, 384)   1152        ['conv2d_105[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 5, 5, 384)   1152        ['conv2d_108[0][0]']
#  Normalization)
#
#  batch_normalization_109 (Batch  (None, 5, 5, 384)   1152        ['conv2d_109[0][0]']
#  Normalization)
#
#  conv2d_110 (Conv2D)            (None, 5, 5, 192)    393408      ['average_pooling2d_10[0][0]']
#
#  batch_normalization_102 (Batch  (None, 5, 5, 320)   960         ['conv2d_102[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_104[0][0]']
#
#  activation_105 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_105[0][0]']
#
#  activation_108 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_108[0][0]']
#
#  activation_109 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_109[0][0]']
#
#  batch_normalization_110 (Batch  (None, 5, 5, 192)   576         ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_102[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 5, 5, 768)    0           ['activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 5, 5, 768)    0           ['activation_108[0][0]',
#                                                                   'activation_109[0][0]']
#
#  activation_110 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_110[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 5, 5, 2048)   0           ['activation_102[0][0]',
#                                                                   'concatenate_14[0][0]',
#                                                                   'concatenate_15[0][0]',
#                                                                   'activation_110[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 5, 5, 448)    917952      ['concatenate_16[0][0]']
#
#  batch_normalization_115 (Batch  (None, 5, 5, 448)   1344        ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_115[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 5, 5, 384)    786816      ['concatenate_16[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 5, 5, 384)    1548672     ['activation_115[0][0]']
#
#  batch_normalization_112 (Batch  (None, 5, 5, 384)   1152        ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 5, 5, 384)   1152        ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_112[0][0]']
#
#  activation_116 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_116[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 5, 5, 384)    442752      ['activation_112[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 5, 5, 384)    442752      ['activation_112[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 5, 5, 384)    442752      ['activation_116[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 5, 5, 384)    442752      ['activation_116[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 5, 5, 2048)  0           ['concatenate_16[0][0]']
#  ooling2D)
#
#  conv2d_111 (Conv2D)            (None, 5, 5, 320)    655680      ['concatenate_16[0][0]']
#
#  batch_normalization_113 (Batch  (None, 5, 5, 384)   1152        ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_114 (Batch  (None, 5, 5, 384)   1152        ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (None, 5, 5, 384)   1152        ['conv2d_117[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 5, 5, 384)   1152        ['conv2d_118[0][0]']
#  Normalization)
#
#  conv2d_119 (Conv2D)            (None, 5, 5, 192)    393408      ['average_pooling2d_11[0][0]']
#
#  batch_normalization_111 (Batch  (None, 5, 5, 320)   960         ['conv2d_111[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_113[0][0]']
#
#  activation_114 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_114[0][0]']
#
#  activation_117 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_117[0][0]']
#
#  activation_118 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_118[0][0]']
#
#  batch_normalization_119 (Batch  (None, 5, 5, 192)   576         ['conv2d_119[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_111[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 5, 5, 768)    0           ['activation_113[0][0]',
#                                                                   'activation_114[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 5, 5, 768)    0           ['activation_117[0][0]',
#                                                                   'activation_118[0][0]']
#
#  activation_119 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_119[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 5, 5, 2048)   0           ['activation_111[0][0]',
#                                                                   'concatenate_17[0][0]',
#                                                                   'concatenate_18[0][0]',
#                                                                   'activation_119[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['concatenate_19[0][0]']
#  2D)
#
#  dropout (Dropout)              (None, 2048)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 2)            4098        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 29,072,610
# Trainable params: 29,027,874
# Non-trainable params: 44,736
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("ModifiedInceptionV3.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.05, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 86/86 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.9192
# Epoch 1: val_accuracy improved from -inf to 0.43056, saving model to ModifiedInceptionV3.h5
# 86/86 [==============================] - 70s 535ms/step - loss: 0.2443 - accuracy: 0.9192 - val_loss: 15.1645 - val_accuracy: 0.4306 - lr: 0.0010
# Epoch 2/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9554
# Epoch 2: val_accuracy improved from 0.43056 to 0.88889, saving model to ModifiedInceptionV3.h5
# 86/86 [==============================] - 41s 480ms/step - loss: 0.1400 - accuracy: 0.9554 - val_loss: 0.5147 - val_accuracy: 0.8889 - lr: 0.0010
# Epoch 3/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9678
# Epoch 3: val_accuracy improved from 0.88889 to 0.95139, saving model to ModifiedInceptionV3.h5
# 86/86 [==============================] - 42s 492ms/step - loss: 0.1135 - accuracy: 0.9678 - val_loss: 0.1712 - val_accuracy: 0.9514 - lr: 0.0010
# Epoch 4/50
# 86/86 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9635
# Epoch 4: val_accuracy did not improve from 0.95139
# 86/86 [==============================] - 40s 467ms/step - loss: 0.1141 - accuracy: 0.9635 - val_loss: 0.1412 - val_accuracy: 0.9514 - lr: 0.0010
# Epoch 5/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9781
# Epoch 5: val_accuracy improved from 0.95139 to 0.97917, saving model to ModifiedInceptionV3.h5
# 86/86 [==============================] - 43s 496ms/step - loss: 0.0832 - accuracy: 0.9781 - val_loss: 0.1110 - val_accuracy: 0.9792 - lr: 0.0010
# Epoch 6/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9773
# Epoch 6: val_accuracy did not improve from 0.97917
# 86/86 [==============================] - 40s 468ms/step - loss: 0.0811 - accuracy: 0.9773 - val_loss: 0.1573 - val_accuracy: 0.9722 - lr: 0.0010
# Epoch 7/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9737
# Epoch 7: val_accuracy did not improve from 0.97917
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 86/86 [==============================] - 40s 467ms/step - loss: 0.0842 - accuracy: 0.9737 - val_loss: 0.1582 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 8/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9821
# Epoch 8: val_accuracy improved from 0.97917 to 0.98611, saving model to ModifiedInceptionV3.h5
# 86/86 [==============================] - 43s 496ms/step - loss: 0.0621 - accuracy: 0.9821 - val_loss: 0.0582 - val_accuracy: 0.9861 - lr: 4.0000e-04
# Epoch 9/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9868
# Epoch 9: val_accuracy did not improve from 0.98611
# 86/86 [==============================] - 41s 477ms/step - loss: 0.0498 - accuracy: 0.9868 - val_loss: 0.0749 - val_accuracy: 0.9792 - lr: 4.0000e-04
# Epoch 10/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9821
# Epoch 10: val_accuracy did not improve from 0.98611
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 86/86 [==============================] - 40s 468ms/step - loss: 0.0626 - accuracy: 0.9821 - val_loss: 0.1921 - val_accuracy: 0.9722 - lr: 4.0000e-04
# Epoch 11/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9839
# Epoch 11: val_accuracy did not improve from 0.98611
# 86/86 [==============================] - 41s 475ms/step - loss: 0.0580 - accuracy: 0.9839 - val_loss: 0.0666 - val_accuracy: 0.9861 - lr: 1.6000e-04
# Epoch 12/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9905
# Epoch 12: val_accuracy did not improve from 0.98611
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 86/86 [==============================] - 40s 468ms/step - loss: 0.0389 - accuracy: 0.9905 - val_loss: 0.0489 - val_accuracy: 0.9861 - lr: 1.6000e-04
# Epoch 13/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9938
# Epoch 13: val_accuracy did not improve from 0.98611
# 86/86 [==============================] - 40s 468ms/step - loss: 0.0288 - accuracy: 0.9938 - val_loss: 0.0540 - val_accuracy: 0.9792 - lr: 6.4000e-05
# Epoch 14/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9949
# Epoch 14: val_accuracy did not improve from 0.98611
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 86/86 [==============================] - 41s 478ms/step - loss: 0.0263 - accuracy: 0.9949 - val_loss: 0.0434 - val_accuracy: 0.9861 - lr: 6.4000e-05
# Epoch 15/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9967
# Epoch 15: val_accuracy improved from 0.98611 to 0.99306, saving model to ModifiedInceptionV3.h5
# 86/86 [==============================] - 42s 489ms/step - loss: 0.0183 - accuracy: 0.9967 - val_loss: 0.0400 - val_accuracy: 0.9931 - lr: 2.5600e-05
# Epoch 16/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9956
# Epoch 16: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 41s 480ms/step - loss: 0.0179 - accuracy: 0.9956 - val_loss: 0.0367 - val_accuracy: 0.9931 - lr: 2.5600e-05
# Epoch 17/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9963
# Epoch 17: val_accuracy did not improve from 0.99306
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 86/86 [==============================] - 41s 472ms/step - loss: 0.0159 - accuracy: 0.9963 - val_loss: 0.0347 - val_accuracy: 0.9931 - lr: 2.5600e-05
# Epoch 18/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9967
# Epoch 18: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 41s 477ms/step - loss: 0.0159 - accuracy: 0.9967 - val_loss: 0.0349 - val_accuracy: 0.9931 - lr: 1.0240e-05
# Epoch 19/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9967
# Epoch 19: val_accuracy did not improve from 0.99306
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 86/86 [==============================] - 41s 478ms/step - loss: 0.0157 - accuracy: 0.9967 - val_loss: 0.0332 - val_accuracy: 0.9931 - lr: 1.0240e-05
# Epoch 20/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9952
# Epoch 20: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 41s 476ms/step - loss: 0.0165 - accuracy: 0.9952 - val_loss: 0.0342 - val_accuracy: 0.9931 - lr: 4.0960e-06
# Epoch 21/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9978
# Epoch 21: val_accuracy did not improve from 0.99306
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 86/86 [==============================] - 41s 475ms/step - loss: 0.0134 - accuracy: 0.9978 - val_loss: 0.0335 - val_accuracy: 0.9931 - lr: 4.0960e-06
# Epoch 22/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9960
# Epoch 22: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 40s 468ms/step - loss: 0.0161 - accuracy: 0.9960 - val_loss: 0.0333 - val_accuracy: 0.9931 - lr: 1.6384e-06
# Epoch 23/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9971
# Epoch 23: val_accuracy did not improve from 0.99306
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 86/86 [==============================] - 41s 478ms/step - loss: 0.0152 - accuracy: 0.9971 - val_loss: 0.0329 - val_accuracy: 0.9931 - lr: 1.6384e-06
# Epoch 24/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9974
# Epoch 24: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 41s 475ms/step - loss: 0.0128 - accuracy: 0.9974 - val_loss: 0.0329 - val_accuracy: 0.9931 - lr: 6.5536e-07
# Epoch 25/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9971
# Epoch 25: val_accuracy did not improve from 0.99306
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 86/86 [==============================] - 40s 467ms/step - loss: 0.0133 - accuracy: 0.9971 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 6.5536e-07
# Epoch 26/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9971
# Epoch 26: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 41s 477ms/step - loss: 0.0123 - accuracy: 0.9971 - val_loss: 0.0328 - val_accuracy: 0.9931 - lr: 2.6214e-07
# Epoch 27/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9978
# Epoch 27: val_accuracy did not improve from 0.99306
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 86/86 [==============================] - 41s 479ms/step - loss: 0.0128 - accuracy: 0.9978 - val_loss: 0.0326 - val_accuracy: 0.9931 - lr: 2.6214e-07
# Epoch 28/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9974
# Epoch 28: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 41s 476ms/step - loss: 0.0131 - accuracy: 0.9974 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 1.0486e-07
# Epoch 29/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9971
# Epoch 29: val_accuracy did not improve from 0.99306
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 86/86 [==============================] - 40s 468ms/step - loss: 0.0142 - accuracy: 0.9971 - val_loss: 0.0328 - val_accuracy: 0.9931 - lr: 1.0486e-07
# Epoch 30/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9978
# Epoch 30: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 40s 469ms/step - loss: 0.0118 - accuracy: 0.9978 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 4.1943e-08
# Epoch 31/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9971
# Epoch 31: val_accuracy did not improve from 0.99306
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 86/86 [==============================] - 40s 469ms/step - loss: 0.0122 - accuracy: 0.9971 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 4.1943e-08
# Epoch 32/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9974
# Epoch 32: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 41s 476ms/step - loss: 0.0151 - accuracy: 0.9974 - val_loss: 0.0326 - val_accuracy: 0.9931 - lr: 1.6777e-08
# Epoch 33/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9967
# Epoch 33: val_accuracy did not improve from 0.99306
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.710887134886434e-09.
# 86/86 [==============================] - 40s 468ms/step - loss: 0.0142 - accuracy: 0.9967 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 1.6777e-08
# Epoch 34/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9974
# Epoch 34: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 40s 469ms/step - loss: 0.0123 - accuracy: 0.9974 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 6.7109e-09
# Epoch 35/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9971
# Epoch 35: val_accuracy did not improve from 0.99306
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.6843547829003003e-09.
# 86/86 [==============================] - 41s 476ms/step - loss: 0.0126 - accuracy: 0.9971 - val_loss: 0.0328 - val_accuracy: 0.9931 - lr: 6.7109e-09
# Epoch 36/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9967
# Epoch 36: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 40s 469ms/step - loss: 0.0132 - accuracy: 0.9967 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 2.6844e-09
# Epoch 37/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9978
# Epoch 37: val_accuracy did not improve from 0.99306
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.0737418953965518e-09.
# 86/86 [==============================] - 40s 468ms/step - loss: 0.0123 - accuracy: 0.9978 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 2.6844e-09
# Epoch 38/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9978
# Epoch 38: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 40s 467ms/step - loss: 0.0112 - accuracy: 0.9978 - val_loss: 0.0328 - val_accuracy: 0.9931 - lr: 1.0737e-09
# Epoch 39/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9978
# Epoch 39: val_accuracy did not improve from 0.99306
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 4.294967492768365e-10.
# 86/86 [==============================] - 41s 475ms/step - loss: 0.0128 - accuracy: 0.9978 - val_loss: 0.0329 - val_accuracy: 0.9931 - lr: 1.0737e-09
# Epoch 40/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9971
# Epoch 40: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 41s 475ms/step - loss: 0.0129 - accuracy: 0.9971 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 4.2950e-10
# Epoch 41/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9971
# Epoch 41: val_accuracy did not improve from 0.99306
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.7179869749028854e-10.
# 86/86 [==============================] - 40s 470ms/step - loss: 0.0130 - accuracy: 0.9971 - val_loss: 0.0328 - val_accuracy: 0.9931 - lr: 4.2950e-10
# Epoch 42/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9971
# Epoch 42: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 40s 469ms/step - loss: 0.0135 - accuracy: 0.9971 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 1.7180e-10
# Epoch 43/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9978
# Epoch 43: val_accuracy did not improve from 0.99306
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.871948010633844e-11.
# 86/86 [==============================] - 41s 476ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 1.7180e-10
# Epoch 44/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9967
# Epoch 44: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 40s 469ms/step - loss: 0.0132 - accuracy: 0.9967 - val_loss: 0.0328 - val_accuracy: 0.9931 - lr: 6.8719e-11
# Epoch 45/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9971
# Epoch 45: val_accuracy did not improve from 0.99306
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.748779259764689e-11.
# 86/86 [==============================] - 40s 469ms/step - loss: 0.0147 - accuracy: 0.9971 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 6.8719e-11
# Epoch 46/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9971
# Epoch 46: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 40s 468ms/step - loss: 0.0134 - accuracy: 0.9971 - val_loss: 0.0326 - val_accuracy: 0.9931 - lr: 2.7488e-11
# Epoch 47/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9974
# Epoch 47: val_accuracy did not improve from 0.99306
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.0995117316614512e-11.
# 86/86 [==============================] - 41s 475ms/step - loss: 0.0128 - accuracy: 0.9974 - val_loss: 0.0326 - val_accuracy: 0.9931 - lr: 2.7488e-11
# Epoch 48/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9971
# Epoch 48: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 41s 474ms/step - loss: 0.0123 - accuracy: 0.9971 - val_loss: 0.0328 - val_accuracy: 0.9931 - lr: 1.0995e-11
# Epoch 49/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9971
# Epoch 49: val_accuracy did not improve from 0.99306
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 4.398046857256866e-12.
# 86/86 [==============================] - 41s 475ms/step - loss: 0.0125 - accuracy: 0.9971 - val_loss: 0.0328 - val_accuracy: 0.9931 - lr: 1.0995e-11
# Epoch 50/50
# 86/86 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9974
# Epoch 50: val_accuracy did not improve from 0.99306
# 86/86 [==============================] - 41s 475ms/step - loss: 0.0142 - accuracy: 0.9974 - val_loss: 0.0327 - val_accuracy: 0.9931 - lr: 4.3980e-12

# %%
#plot the loss curve
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.ylabel('Loss',fontweight='bold')
plt.title('Loss Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('ModIncepV3LossCurve',dpi=400)
plt.legend()

# %%
#plot the accuracy curve
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.ylabel('Accuracy',fontweight='bold')
plt.title('Accuracy Curve',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
plt.savefig('ModIncepV3_AccCurve',dpi=400)
plt.legend()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 10/10 [==============================] - 3s 142ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       210
#            1       0.99      0.98      0.99       110
#
#     accuracy                           0.99       320
#    macro avg       0.99      0.99      0.99       320
# weighted avg       0.99      0.99      0.99       320

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True/Actual label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm,labels)
plt.savefig('ModIncepV3CM',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
print('TP = %.5f'%TP, 'TN = %.5f'%TN, 'FP = %.5f'%FP, 'FN = %.5f'%FN)
# Out:
# TP = 108.00000 TN = 209.00000 FP = 1.00000 FN = 2.00000

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.5f' % accuracy_score(y_test_new, pred), 'Precision: %.5f' % precision_score(y_test_new, pred),' Recall: %.5f' % recall_score(y_test_new, pred), 
      'F1 Score: %.5f' % f1_score(y_test_new, pred), 'AUC Score: %.5f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.99062 Precision: 0.99083  Recall: 0.98182 F1 Score: 0.98630 AUC Score: 0.98853

# %%
recall=TP/float(TP+FN)
print(recall)
print(recall_score(y_test_new, pred))
# Out:
# 0.9818181818181818
# 0.9818181818181818

# %%
precision=TP/float(TP+FP)
print(precision)

print(precision_score(y_test_new, pred))
# Out:
# 0.9908256880733946
# 0.9908256880733946

# %%
print((2*precision*recall)/(recall+precision))
print(f1_score(y_test_new, pred))
# Out:
# 0.9863013698630138
# 0.9863013698630138

# %%
specificity=TN/float(TN+FP)
print(specificity)
# Out:
# 0.9952380952380953

# %%
print(TP/float(TP+FN))
print(recall_score(y_test_new, pred))
# Out:
# 0.9818181818181818
# 0.9818181818181818

# %%
print(roc_auc_score(y_test_new, pred))
# Out:
# 0.9885281385281386

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test_new, pred)
# Out:
# 0.009375

# %%
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.4f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([-0.02,1.0])
plt.ylim([0.0,1.02])
plt.ylabel('Recall')
plt.xlabel('Fall-out (1-Specificity)')
plt.savefig('ModIncepV3_ROCCurve1',dpi=400)
plt.show()

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
print('Validation acc: {0:0.2f}%'.format(np.round((history.history['val_accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 99.06%
# Precision: 99.08%
# Recall or Sensitivity: 98.18%
# Specificity: 99.52%
# F1-score: 98.63%
# AUC-score: 98.85%
# Train acc: 99.74%
# Validation acc: 99.31%

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

# %%
from scipy import interp
from itertools import cycle

# %%
# Plot linewidth.
lw = 1

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test_new, pred)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_new.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(2)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(2):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= 2

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
plt.title('Receiver Operating Characteristic (ROC) Curve')
# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'cornflowerblue'])
for i, color in zip(range(2), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.02,1.0])
plt.ylim([0.0,1.02])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.savefig('ModIncepV3ROC1',dpi=400)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
